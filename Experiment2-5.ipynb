# %% [markdown]
# # Test for model testing
# ## Experiment 2
# Movement with statification

# %%
import random
import pathlib
import itertools
import collections
import os
import cv2
import numpy as np
# import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load in the classifications

# %%
saveLocation = "D:/Thesis/Video-Auslan-sorted"
pathMovement = {}
for word in os.listdir(saveLocation):
    if word == 'AREA-2H':
        print(word)
    pathMovement[word] = None
    
f = open("keyBinds.txt", "r")
line = f.readline()
i= 0
while (line):
    try:
        if line.split("_|_")[1] == 'None\n':
            pathMovement[line.split("_|_")[0]] = None
        else:
            pathMovement[line.split("_|_")[0]] = line.split("_|_")[1]
    except:
        j = 1
    line = f.readline()
f.close()
pathMovement, i
# Out:
# AREA-2H
# ({'ABOUT1': 'Vertical Circular\n',
#   'ABOUT2': 'Vertical Circular\n',
#   'ABOUT2(7)': 'Vertical Circular\n',
#   'ABOUT2(B)': None,
#   'ABOUT2(FALSE-START)': 'Unknown\n',
#   'ACCEPT': 'Towards\n',
#   'ACCOMMODATION-2H': 'Back and Forth\n',
#   'ACCURATE': 'Up and Down\n',
#   'ACHIEVE': 'Away\n',
#   'ACTIVITY-THERE': 'Sideways\n',
#   'ADULT': 'Horizontal Circular\n',
#   'AFRAID': 'Back and Forth\n',
#   'AFTERNOON': 'Local Movement\n',
#   'AFTERNOON3': 'Towards\n',
#   'AFTERNOON4': 'Towards\n',
#   'AGAIN': 'Down\n',
#   'AGAIN(8)': None,
#   'AGAIN-2H': 'Local Movement\n',
#   'AGAIN-AND-AGAIN': 'Up and Down\n',
#   'AGES': 'Horizontal Circular\n',
#   'AGREE': 'Sideways\n',
#   'AIM': 'Unknown\n',
#   'ALIVE': 'Towards\n',
#   'ALL': 'Horizontal Circular\n',
#   'ALL-2H': 'Away\n',
#   'ALL-DAY': 'Up\n',
#   'ALL-DAY-2H': 'Horizontal Circular\n',
#   'ALL-DAY-LONG': 'Vertical Circular\n',
#   'ALLOW': 'Local Movement\n',
#   'ALMOST': 'Unknown\n',
#   'ALMOST(FLATGO)': None,
#   'ALMOST-2H': 'Unknown\n',
#   'ALRIGHT': 'Unknown\n',
#   'ALRIGHT-2H': 'Unknown\n',
#   'ALRIGHT2': 'Local Movement\n',
#   'ALWAYS': 'Away\n',
#   'ALWAYS1': 'Away\n',
#   'ALWAYS2': 'Up\n',
#   'AMERINDIAN': 'Local Movement\n',
#   'AMERINDIAN(FALSE START)': 'Up\n',
#   'AMERINDIAN2': 'Up\n',
#   'AMERINDIAN2(FALSE START)': 'Unknown\n',
#   'AND-THEN': 'Local Movement\n',
#   'AND1': 'Away\n',
#   'ANGRY': 'Unknown\n',
#   'ANGRY-2H': 'Up\n',
#   'ANGRY1': 'Up and Down\n',
#   'ANGRY1-2H': 'Up\n',
#   'ANIMAL': 'Vertical Circular\n',
#   'ANNOUNCE': 'Back and Forth\n',
#   'ANNOYED': 'Up\n',
#   'ANOTHER': 'Unknown\n',
#   'ANSWER': 'Down\n',
#   'APOSTROPHE': 'Unknown\n',
#   'APPROACH': 'Unknown\n',
#   'APPROACH-CLOSE': 'Towards\n',
#   'AREA': 'Horizontal Circular\n',
#   'AREA-2H': 'Horizontal Circular\n',
#   'ARGUE': 'Up and Down\n',
#   'ARM(5)': 'Unknown\n',
#   'AROUND': 'Horizontal Circular\n',
#   'AROUND-1H(R-VERT)': None,
#   'ARRIVE': 'Up and Down\n',
#   'ARRIVE(FALSE-START)': 'Unknown\n',
#   'ARRIVE(IRISHK)-1H': 'Unknown\n',
#   'ASK': 'Unknown\n',
#   'AT-HEART': 'Local Movement\n',
#   'ATTACK': 'Away\n',
#   'ATTEND': 'Sideways\n',
#   'ATTEND2': 'Unknown\n',
#   'ATTENTION': 'Unknown\n',
#   'ATTENTION2': 'Unknown\n',
#   'ATTRACT': 'Unknown\n',
#   'AVERAGE': 'Sideways\n',
#   'AWAY': 'Away\n',
#   'AWKWARD': 'Side to Side\n',
#   'B(FALSE-START)': 'Unknown\n',
#   'BABY': 'Side to Side\n',
#   'BACK': 'Towards\n',
#   'BACK(1)': 'Towards\n',
#   'BACK-HEAD': 'Unknown\n',
#   'BACK-SHOULDER': 'Local Movement\n',
#   'BACK2': 'Unknown\n',
#   'BAD': 'Local Movement\n',
#   'BAD(Y)': 'Local Movement\n',
#   'BAD-2H': 'Local Movement\n',
#   'BAD-LUCK': 'Local Movement\n',
#   'BALANCE': 'Up and Down\n',
#   'BALL': 'Unknown\n',
#   'BALL1': 'Local Movement\n',
#   'BALL1(5)': 'Local Movement\n',
#   'BALL1(B)': 'Local Movement\n',
#   'BALL1-1H': 'Unknown\n',
#   'BALL2': 'Local Movement\n',
#   'BALL2-1H': 'Unknown\n',
#   'BALL3': 'Unknown\n',
#   'BAN': 'Unknown\n',
#   'BAN(1)': 'Unknown\n',
#   'BANANA1': 'Local Movement\n',
#   'BANANA2': 'Sideways\n',
#   'BARK': 'Local Movement\n',
#   'BASIN': 'Away\n',
#   'BATH': 'Up and Down\n',
#   'BATH(B)': 'Down\n',
#   'BATH(B)-H1': 'Up and Down\n',
#   'BEAT': 'Local Movement\n',
#   'BEAUTIFUL': 'Unknown\n',
#   'BEAUTIFUL(SE)': 'Unknown\n',
#   'BECAUSE1': 'Unknown\n',
#   'BECAUSE2': 'Unknown\n',
#   'BECAUSE3': 'Unknown\n',
#   'BECKON2': 'Local Movement\n',
#   'BECKON2-2H': 'Local Movement\n',
#   'BECOME': 'Up and Down\n',
#   'BECOME(IRISHT)': 'Vertical Circular\n',
#   'BECOME1B(IRISHT)': 'Up and Down\n',
#   'BED': 'Unknown\n',
#   'BED-2H': 'Unknown\n',
#   'BED1': 'Unknown\n',
#   'BED2': 'Down\n',
#   'BED2-2H': 'Unknown\n',
#   'BEDFRAME': None,
#   'BEDROOM2': 'Unknown\n',
#   'BEE': 'Unknown\n',
#   'BEE(FLATO)': 'Up\n',
#   'BEE(IRISHK)': 'Unknown\n',
#   'BEE-2H': None,
#   'BEFORE-THAT': 'Towards\n',
#   'BEFORE-THAT(1)': 'Towards\n',
#   'BEFORE-THAT(1)-1H': 'Towards\n',
#   'BEFORE1': 'Local Movement\n',
#   'BEFORE1(FALSE-START)': 'Unknown\n',
#   'BEFORE2': None,
#   'BEG3': 'Unknown\n',
#   'BEGIN': 'Down\n',
#   'BEGIN(FALSE-START)': 'Unknown\n',
#   'BEGIN(HTHUMB)-1H': 'Down\n',
#   'BEGIN-1H': 'Down\n',
#   'BELIEVE': 'Local Movement\n',
#   'BELIEVE-NOT2': 'Away\n',
#   'BELIEVE2': 'Down\n',
#   'BELIEVE2(FALSE-START)': 'Unknown\n',
#   'BELIEVE2-NOT': 'Away\n',
#   'BELONG2': 'Unknown\n',
#   'BESIDE': 'Local Movement\n',
#   'BEST': 'Unknown\n',
#   'BET': 'Back and Forth\n',
#   'BET1': 'Back and Forth\n',
#   'BET1(B)': 'Unknown\n',
#   'BETTER': 'Local Movement\n',
#   'BIG': 'Sideways\n',
#   'BIG(BENT7)': 'Unknown\n',
#   'BIG-CHEST': None,
#   'BIG1': 'Sideways\n',
#   'BIG2': 'Sideways\n',
#   'BIG3': 'Unknown\n',
#   'BIRD': 'Local Movement\n',
#   'BIRD(FALSE-START)': 'Unknown\n',
#   'BIRTH': 'Side to Side\n',
#   'BISCUIT': 'Local Movement\n',
#   'BIT': 'Unknown\n',
#   'BITE': 'Towards\n',
#   'BITE-2H': 'Away\n',
#   'BITE1': 'Towards\n',
#   'BLACK': 'Down\n',
#   'BLACK2': 'Unknown\n',
#   'BLANK': 'Horizontal Circular\n',
#   'BLANK-1H': 'Unknown\n',
#   'BLANKET': 'Towards\n',
#   'BLAST': 'Unknown\n',
#   'BLAZING-SUN': 'Local Movement\n',
#   'BLESS-YOU': 'Local Movement\n',
#   'BLOCK': 'Unknown\n',
#   'BLOCK(BC)': 'Away\n',
#   'BLOCK2': 'Unknown\n',
#   'BLOOD': None,
#   'BLUR': 'Sideways\n',
#   'BODY': 'Unknown\n',
#   'BOOK': 'Local Movement\n',
#   'BOOK-OPEN': None,
#   'BOOT': 'Local Movement\n',
#   'BOOTS': 'Local Movement\n',
#   'BORED': 'Sideways\n',
#   'BORING': 'Sideways\n',
#   'BORING1': 'Sideways\n',
#   'BORING2': 'Back and Forth\n',
#   'BORN1': None,
#   'BORN2': None,
#   'BOTH': 'Side to Side\n',
#   'BOTH-2H': None,
#   'BOTH1': 'Local Movement\n',
#   'BOTHER': 'Unknown\n',
#   'BOTHER(S)': 'Local Movement\n',
#   'BOTHER(S)-1H': None,
#   'BOTHER-NOT': 'Away\n',
#   'BOTTOM': 'Down\n',
#   'BOTTOM2': None,
#   'BOW': 'Down\n',
#   'BOW-TIE1': 'Sideways\n',
#   'BOWL': 'Unknown\n',
#   'BOWLING': 'Away\n',
#   'BOX': 'Unknown\n',
#   'BOY': 'Side to Side\n',
#   'BOY(BENT2)': None,
#   'BOY(FALSE START)': 'Unknown\n',
#   'BOY(FALSE-START)': 'Unknown\n',
#   'BOY1': 'Side to Side\n',
#   'BOY1(FALSE-START)': 'Unknown\n',
#   'BOY1(IRISHH)': 'Unknown\n',
#   'BOY1(P)': 'Sideways\n',
#   'BOY2': 'Unknown\n',
#   'BREAK': 'Sideways\n',
#   'BREAK(5)': 'Local Movement\n',
#   'BREAK-5': 'Unknown\n',
#   'BREAK-WIND-2H': 'Side to Side\n',
#   'BREAK2': 'Sideways\n',
#   'BREATHE': 'Back and Forth\n',
#   'BREATHE-2H': 'Back and Forth\n',
#   'BRICK': 'Unknown\n',
#   'BRICK2': 'Up\n',
#   'BRICK2(BC)': 'Up and Down\n',
#   'BRICKLAYER': 'Up\n',
#   'BRICKLAYER(6)': 'Back and Forth\n',
#   'BRICKLAYER(B)': 'Back and Forth\n',
#   'BRICKLAYER(IRISHT)': 'Side to Side\n',
#   'BRIDGE': 'Sideways\n',
#   'BRIDGE(FALSE START)': 'Unknown\n',
#   'BRIDGE-1H': 'Sideways\n',
#   'BRIDGE2': 'Sideways\n',
#   'BRING': 'Sideways\n',
#   'BROWN1': 'Local Movement\n',
#   'BRUSH': 'Down\n',
#   'BRUSH(FALSE START)': 'Unknown\n',
#   'BRUSH-2H': 'Down\n',
#   'BUILD': 'Up and Down\n',
#   'BUILD(H)': 'Up and Down\n',
#   'BUILD1A': 'Up and Down\n',
#   'BUILD1B': 'Up and Down\n',
#   'BUILDING': 'Up and Down\n',
#   'BUILDING-H': 'Up and Down\n',
#   'BULLSHIT': None,
#   'BULLSHIT2-2H': 'Down\n',
#   'BUN-HAIR': 'Unknown\n',
#   'BURROW(B)': 'Side to Side\n',
#   'BURST': 'Side to Side\n',
#   'BUSH': 'Vertical Circular\n',
#   'BUSINESS': 'Towards\n',
#   'BUSY': 'Back and Forth\n',
#   'BUT2': 'Unknown\n',
#   'BYE': 'Side to Side\n',
#   'CAKE': 'Up and Down\n',
#   'CAKE(IRISHK)': 'Up and Down\n',
#   'CALCULATE': 'Down\n',
#   'CALL': None,
#   'CALL2': 'Away\n',
#   'CALLED': 'Down\n',
#   'CALM': 'Down\n',
#   'CAMERA2': 'Local Movement\n',
#   'CAN': 'Away\n',
#   'CAN(FALSE-START)': 'Unknown\n',
#   'CAN-NOT': 'Sideways\n',
#   'CAN-NOT-2H': 'Sideways\n',
#   'CANNOT': 'Sideways\n',
#   'CAPTURE2': 'Unknown\n',
#   'CAPTURE2-1H': None,
#   'CAR': 'Horizontal Circular\n',
#   'CAR-1H': 'Horizontal Circular\n',
#   'CAR2': 'Up and Down\n',
#   'CAR2-1H': 'Unknown\n',
#   'CARE': 'Down\n',
#   'CARE-NOT': 'Away\n',
#   'CARELESS(1)': 'Away\n',
#   'CARTOON': 'Back and Forth\n',
#   'CARTOON-CHEEK': None,
#   'CAT': 'Side to Side\n',
#   'CAT(FLATBC)': 'Side to Side\n',
#   'CAT-1H': 'Unknown\n',
#   'CAT1': 'Unknown\n',
#   'CAT1(FALSE START)': 'Unknown\n',
#   'CAT2': 'Side to Side\n',
#   'CAT2(12)': 'Side to Side\n',
#   'CAT2(F)': 'Unknown\n',
#   'CAT2(FBC)': 'Unknown\n',
#   'CAT2(HTHUMB)': 'Unknown\n',
#   'CAT2(P)': 'Unknown\n',
#   'CAT2(X)': 'Unknown\n',
#   'CAT2-1H': 'Sideways\n',
#   'CAT2-2H': 'Unknown\n',
#   'CAT2-H': 'Unknown\n',
#   'CATCH': 'Horizontal Circular\n',
#   'CATCH(FALSE-START)': 'Unknown\n',
#   'CATCH-1H': 'Unknown\n',
#   'CATCH-2H': 'Down\n',
#   'CATCH-UP-WITH': 'Unknown\n',
#   'CATTLE': 'Up\n',
#   'CATTLE(FALSE-START)': None,
#   'CAUGHT-BY-SURPRISE': 'Towards\n',
#   'CEILING': 'Away\n',
#   'CEILING-2H': 'Away\n',
#   'CENTRE': 'Local Movement\n',
#   'CENTRE-1H': 'Unknown\n',
#   'CHAIR': 'Down\n',
#   'CHAIR(B)': 'Down\n',
#   'CHAIR(BENTB)': 'Down\n',
#   'CHAIR1(SE)': 'Down\n',
#   'CHAIR2': 'Down\n',
#   'CHAIR2(BENTB)': 'Down\n',
#   'CHALLENGE': 'Unknown\n',
#   'CHANGE': 'Sideways\n',
#   'CHANGE(B)': 'Unknown\n',
#   'CHANGE-MIND(NEUTRAL-SPACE)': 'Unknown\n',
#   'CHANGE1(IRISHT)': None,
#   'CHANGE2': 'Unknown\n',
#   'CHASE': 'Away\n',
#   'CHASE-1H': 'Unknown\n',
#   'CHASE2': 'Vertical Circular\n',
#   'CHATTERBOX': 'Away\n',
#   'CHECK2': 'Unknown\n',
#   'CHEEKY': 'Unknown\n',
#   'CHEESE3': 'Side to Side\n',
#   'CHERISH': 'Up and Down\n',
#   'CHERISH-1H': None,
#   'CHERISH1': 'Up and Down\n',
#   'CHEW': 'Side to Side\n',
#   'CHILD': 'Down\n',
#   'CHILDREN': 'Sideways\n',
#   'CHILDREN1-2H': 'Sideways\n',
#   'CHILDREN2-2H': 'Sideways\n',
#   'CHOOSE': None,
#   'CIRCLE': 'Vertical Circular\n',
#   'CITY': 'Up and Down\n',
#   'CLEAN': 'Back and Forth\n',
#   'CLEAN3': 'Vertical Circular\n',
#   'CLEAN3B': 'Horizontal Circular\n',
#   'CLEAR': 'Sideways\n',
#   'CLEVER': 'Sideways\n',
#   'CLIFF': 'Down\n',
#   'CLIFF(FALSE-START)': None,
#   'CLIFF-2H': 'Down\n',
#   'CLIMB': 'Up and Down\n',
#   'CLIMB-1H': 'Unknown\n',
#   'CLIMB1': 'Sideways\n',
#   'CLIMB2': 'Unknown\n',
#   'CLIMB3': 'Unknown\n',
#   'CLOSE(FALSE START)': 'Unknown\n',
#   'CLOSE-SHUT': 'Down\n',
#   'CLOTHES': 'Up and Down\n',
#   'CLOTHES1': 'Up and Down\n',
#   'CLUB': 'Up and Down\n',
#   'COAT': 'Sideways\n',
#   'COAT(BENTB)': 'Sideways\n',
#   'COAT(IRISHT)': 'Sideways\n',
#   'COFFEE': 'Unknown\n',
#   'COINCIDENCE': 'Up and Down\n',
#   'COLD': 'Side to Side\n',
#   'COLD(FALSE-START)': 'Unknown\n',
#   'COLLECT': 'Unknown\n',
#   'COLLECT1A': 'Unknown\n',
#   'COLLECT2': 'Unknown\n',
#   'COLLECT2-1H': 'Unknown\n',
#   'COMB': 'Up and Down\n',
#   'COME': 'Towards\n',
#   'COME(BENTB)': 'Unknown\n',
#   'COME-2H': 'Towards\n',
#   'COME-ON': 'Up and Down\n',
#   'COMMON': None,
#   'COMMUNICATE': 'Back and Forth\n',
#   'COMMUNITY': 'Sideways\n',
#   'COMPETE': 'Sideways\n',
#   'COMPLETE': 'Away\n',
#   'CONFIRM': 'Up and Down\n',
#   'CONSIDER': 'Vertical Circular\n',
#   'CONSIDER-2H': 'Unknown\n',
#   'CONSIDER-2H(CG)': 'Vertical Circular\n',
#   'CONSIDER1B': 'Vertical Circular\n',
#   'CONSIDER1C': 'Unknown\n',
#   'CONTINUE': 'Up and Down\n',
#   'CONTINUE(1)': 'Up and Down\n',
#   'CONTINUE-1H': 'Up and Down\n',
#   'CONTROL': 'Back and Forth\n',
#   'COOL': 'Unknown\n',
#   'CORN': 'Unknown\n',
#   'CORN1-2H': 'Unknown\n',
#   'CORN3': 'Unknown\n',
#   'CORNER': 'Sideways\n',
#   'COUNTRY': 'Unknown\n',
#   'COW': 'Up\n',
#   'COW(FALSE-START)': 'Unknown\n',
#   'COWBOY': 'Up and Down\n',
#   'COWBOY(1)': 'Up and Down\n',
#   'COWBOY(2)': 'Up and Down\n',
#   'COWBOY(HTHUMB)': 'Up and Down\n',
#   'CRANKY': 'Unknown\n',
#   'CRAZY1': None,
#   'CREEK(2)': None,
#   'CRIED': 'Unknown\n',
#   'CROWD': 'Unknown\n',
#   'CRY': 'Up and Down\n',
#   'CRY-1H': 'Up and Down\n',
#   'CRY1': 'Down\n',
#   'CUDDLE': 'Towards\n',
#   'CURIOUS': 'Vertical Circular\n',
#   'CUT-STOP': None,
#   'CUTE': 'Unknown\n',
#   'DAMAGE': 'Away\n',
#   'DAMN': 'Unknown\n',
#   'DAMN2': 'Away\n',
#   'DANCE1': 'Up and Down\n',
#   'DANGER': 'Back and Forth\n',
#   'DANGER1': 'Back and Forth\n',
#   'DANGER2': 'Up and Down\n',
#   'DARE': 'Up\n',
#   'DARE1': 'Unknown\n',
#   'DARK': 'Unknown\n',
#   'DASH-OFF': 'Sideways\n',
#   'DAY': 'Sideways\n',
#   'DAY-1H': 'Sideways\n',
#   'DAYBREAK': None,
#   'DEAD': None,
#   'DEAD(B)': 'Unknown\n',
#   'DEAL-CARDS': 'Back and Forth\n',
#   'DECEIVE': 'Away\n',
#   'DECIDE': 'Down\n',
#   'DECIDE2': 'Unknown\n',
#   'DEEP': 'Down\n',
#   'DEER': 'Away\n',
#   'DEER(4)': 'Away\n',
#   'DEER(FALSE-START)': 'Unknown\n',
#   'DEER(Y)': 'Unknown\n',
#   'DEER-Y': 'Unknown\n',
#   'DEFEAT1': 'Down\n',
#   'DEFEAT2': 'Down\n',
#   'DELAY': None,
#   'DELICIOUS': 'Unknown\n',
#   'DELICIOUS3': 'Unknown\n',
#   'DEMAND': 'Back and Forth\n',
#   'DEPRESS': 'Down\n',
#   'DEPRESSED': 'Down\n',
#   'DEPTH': 'Down\n',
#   'DESPONDENT': 'Down\n',
#   'DETERMINATE': None,
#   'DETERMINED': 'Unknown\n',
#   'DETERMINED2': None,
#   'DIE': 'Unknown\n',
#   'DIE1': 'Away\n',
#   'DIFFERENT': 'Sideways\n',
#   'DIFFICULT2': 'Unknown\n',
#   'DIMINISH': 'Unknown\n',
#   'DINNER': 'Up and Down\n',
#   'DINNER(FALSE-START)': 'Unknown\n',
#   'DISAPPEAR': 'Sideways\n',
#   'DISAPPEAR(FALSE-START)': 'Unknown\n',
#   'DISAPPEAR1': 'Sideways\n',
#   'DISAPPEAR2': 'Away\n',
#   'DISAPPEAR2(O)': None,
#   'DISAPPEAR2-2H': None,
#   'DISAPPEAR3': 'Away\n',
#   'DISAPPEAR3B+4': 'Away\n',
#   'DISAPPOINTED': 'Unknown\n',
#   'DISCIPLINE': 'Up and Down\n',
#   'DISCUSS1': 'Unknown\n',
#   'DISPERSE': 'Away\n',
#   'DISTINGUISHED': 'Side to Side\n',
#   'DIZZY': 'Vertical Circular\n',
#   'DO': 'Unknown\n',
#   'DO-SE': None,
#   'DO-THERE': 'Unknown\n',
#   'DO-THERE-2H': 'Unknown\n',
#   'DOCUMENT': 'Down\n',
#   'DOG': 'Up and Down\n',
#   'DOG(FALSE START)': 'Unknown\n',
#   'DOG(FALSE-START)': 'Unknown\n',
#   'DOG-2H': 'Unknown\n',
#   'DOG1': 'Down\n',
#   'DOG2': 'Unknown\n',
#   'DOG2(FALSE-START)': 'Unknown\n',
#   'DOG2-2H': 'Unknown\n',
#   'DOLLAR1': 'Sideways\n',
#   "DON'T": 'Unknown\n',
#   "DON'T-KNOW": 'Unknown\n',
#   "DON'T1-2H": None,
#   'DONE(SE)': None,
#   'DOOR': 'Unknown\n',
#   'DOOR(FALSE START)': 'Away\n',
#   'DOOR-OPEN': 'Towards\n',
#   'DOUBT': 'Up and Down\n',
#   'DOUBT(5)': 'Up and Down\n',
#   'DOUBT-2h': 'Up and Down\n',
#   'DOWN-B': 'Down\n',
#   'DRAW-ATTENTION': 'Unknown\n',
#   'DRAW-LINE': 'Horizontal Circular\n',
#   'DREAM': None,
#   'DRESS': 'Up and Down\n',
#   'DRESS1C': 'Unknown\n',
#   'DRINK': None,
#   'DRIVE': 'Away\n',
#   'DROP': 'Down\n',
#   'DROP-2H': 'Down\n',
#   'DROP1': 'Down\n',
#   'DRY': None,
#   'DSM(1-VERT)ENTITY-UP-OVER-THERE': 'Up\n',
#   'DSM(2-DOWN)ANIMAL-RUNS': 'Unknown\n',
#   'DSM(BENT2);REACHING-HIGH-POINT': 'Unknown\n',
#   'DULL': 'Sideways\n',
#   'DUNNO': 'Unknown\n',
#   'EAGER': 'Back and Forth\n',
#   'EARLY': 'Unknown\n',
#   'EASY': 'Unknown\n',
#   'EAT': 'Towards\n',
#   'EAT(FALSE-START)': 'Unknown\n',
#   'EAT(MID)': 'Towards\n',
#   'EAT-2H': 'Back and Forth\n',
#   'EDUCATE': None,
#   'EDUCATE-1H': 'Away\n',
#   'EIGHT': 'Unknown\n',
#   'ELIMINATE': 'Away\n',
#   'ELIMINATE1': 'Away\n',
#   'EMIT': 'Unknown\n',
#   'EMPTY': 'Away\n',
#   'ENCOURAGE1': 'Sideways\n',
#   'ENCOURAGE1-HERD': 'Sideways\n',
#   'END': 'Away\n',
#   'ENJOY': 'Unknown\n',
#   'ENJOY2': 'Unknown\n',
#   'ENOUGH': 'Up and Down\n',
#   'EQUAL': 'Away\n',
#   'ESCAPE': 'Away\n',
#   'ESCAPE-IRISHH': 'Unknown\n',
#   'EVERY': 'Away\n',
#   'EVERYDAY': 'Unknown\n',
#   'EVERYTHING': 'Unknown\n',
#   'EXCELLENT': 'Away\n',
#   'EXCELLENT(Y)': 'Unknown\n',
#   'EXCITE': 'Up and Down\n',
#   'EXCITED': 'Up and Down\n',
#   'EXCITING': 'Up and Down\n',
#   'EXPENSIVE': 'Unknown\n',
#   'EXPLODE': 'Side to Side\n',
#   'EXPLORE': 'Unknown\n',
#   'EXTINGUISH': None,
#   'EYELASHES': None,
#   'FACE': 'Vertical Circular\n',
#   'FACE1': 'Vertical Circular\n',
#   'FACIAL-EXPRESSION': 'Up and Down\n',
#   'FACING': 'Unknown\n',
#   'FADE': 'Sideways\n',
#   'FAIL': 'Down\n',
#   'FAINT': 'Down\n',
#   'FAIR': 'Back and Forth\n',
#   'FALL': 'Down\n',
#   'FALL-1H': 'Down\n',
#   'FALL-2H': 'Down\n',
#   'FALL-IN-LOVE': 'Unknown\n',
#   'FALSE-START': 'Unknown\n',
#   'FAMILY': 'Unknown\n',
#   'FAMILY(FALSE-START)': 'Unknown\n',
#   'FAMOUS': 'Sideways\n',
#   'FAR': 'Up\n',
#   'FAR(1)': 'Away\n',
#   'FAR-2H': 'Away\n',
#   'FAR2': 'Away\n',
#   'FARM': 'Down\n',
#   'FARM(SE)': None,
#   'FARM1': 'Down\n',
#   'FARM3': 'Sideways\n',
#   'FART': None,
#   'FAST': 'Down\n',
#   'FAST(FALSE-START)': 'Unknown\n',
#   'FAST1': 'Down\n',
#   'FAST2': 'Away\n',
#   'FAT': 'Sideways\n',
#   'FATHER': None,
#   'FAULT': None,
#   'FBUOY': 'Towards\n',
#   'FEAR': None,
#   'FED-UP': None,
#   'FEEL': 'Up\n',
#   'FEEL-2H': 'Up\n',
#   'FEEL-FIT': 'Back and Forth\n',
#   'FENCE': 'Away\n',
#   'FETCH': 'Unknown\n',
#   'FETCH-1H': 'Unknown\n',
#   'FEW': 'Unknown\n',
#   'FEW(FALSE-START)': 'Unknown\n',
#   'FICTION-2H': None,
#   'FIFTEEN': 'Unknown\n',
#   'FIFTH2': 'Unknown\n',
#   'FILL': 'Unknown\n',
#   'FILL-1H': 'Up\n',
#   'FILM2': 'Unknown\n',
#   'FINALLY': 'Unknown\n',
#   'FIND': 'Unknown\n',
#   'FIND(B)': 'Towards\n',
#   'FIND(FALSE-START)': 'Towards\n',
#   'FIND(X)': 'Unknown\n',
#   'FIND-7X': None,
#   'FIND-X': 'Unknown\n',
#   'FIND1': None,
#   'FIND1A(X)': 'Towards\n',
#   'FIND2': 'Unknown\n',
#   'FINE': 'Back and Forth\n',
#   'FINE-2H': 'Unknown\n',
#   'FINGERSPELL': 'Unknown\n',
#   'FINISH-FIVE': None,
#   'FINISH.FIVE': 'Unknown\n',
#   'FINISH.FIVE-1H': 'Unknown\n',
#   'FINISH.GOOD': 'Side to Side\n',
#   'FINISH.GOOD(FALSE-START)': 'Unknown\n',
#   'FINISH.GOOD-2H': 'Unknown\n',
#   'FIRE': 'Up\n',
#   'FIRST': 'Unknown\n',
#   'FIRST-OF-ONE': 'Unknown\n',
#   'FIRST1': 'Unknown\n',
#   'FIRST2': 'Unknown\n',
#   'FIVE': 'Unknown\n',
#   'FLABBERGASTED': 'Down\n',
#   'FLAT': 'Sideways\n',
#   'FLAT-SURFACE': 'Sideways\n',
#   'FLOOR': 'Sideways\n',
#   'FLOWER': 'Sideways\n',
#   'FLOWER(F)': 'Sideways\n',
#   'FLUKE': 'Unknown\n',
#   'FLY': 'Up and Down\n',
#   'FLY1': 'Up and Down\n',
#   'FLY1B': 'Up and Down\n',
#   'FLY2': 'Up and Down\n',
#   'FOLLOW': 'Away\n',
#   'FOLLOW2': 'Away\n',
#   'FOOL': 'Up\n',
#   'FOOTSTEPS(5)': 'Back and Forth\n',
#   'FOOTSTEPS(O)': 'Back and Forth\n',
#   'FOR': 'Down\n',
#   'FOR-A-WHILE': None,
#   'FOR1': 'Unknown\n',
#   'FOR2': 'Unknown\n',
#   'FORBID': 'Sideways\n',
#   'FORCE': 'Towards\n',
#   'FORCE-A-SMILE': 'Up\n',
#   'FORGET': 'Unknown\n',
#   'FORGET2-2H': None,
#   'FORWARD-1H': None,
#   'FOUND-OUT': 'Unknown\n',
#   'FOUND-OUT(FALSE-START)': 'Unknown\n',
#   'FOUR': 'Unknown\n',
#   'FOURTH2': 'Unknown\n',
#   'FREE': 'Unknown\n',
#   'FRIEND': 'Up and Down\n',
#   'FRIGHTENED': 'Towards\n',
#   'FROG': 'Up and Down\n',
#   'FROG2': 'Up and Down\n',
#   'FROM': 'Unknown\n',
#   'FROM1': 'Away\n',
#   'FRONT': 'Back and Forth\n',
#   'FRONT1': 'Towards\n',
#   'FRUSTRATED': None,
#   'FRUSTRATED-1H': 'Vertical Circular\n',
#   'FRUSTRATED2': 'Vertical Circular\n',
#   'FRUSTRATED2-1h': 'Vertical Circular\n',
#   'FRUSTRATED2B': 'Towards\n',
#   'FUCK': 'Unknown\n',
#   'FUCK-OFF-ALL': None,
#   'FUCK-YOU': None,
#   'FUCK2': 'Down\n',
#   'FUCK2-1H': 'Unknown\n',
#   'FULL': 'Unknown\n',
#   'FUN': 'Unknown\n',
#   'FUNNY': None,
#   'FUNNY-STRANGE': 'Unknown\n',
#   'FURNITURE2': 'Down\n',
#   'G(CA)': 'Unknown\n',
#   'G(NMS)': None,
#   'GALLOP': 'Unknown\n',
#   'GAME': 'Unknown\n',
#   'GATE-CLOSE(H)': 'Sideways\n',
#   'GATE-OPEN(H)': 'Away\n',
#   'GATHER': None,
#   'GET': 'Towards\n',
#   'GET(SE)': 'Down\n',
#   'GET-ATTENTION': 'Up and Down\n',
#   'GET-ATTENTION-1H': 'Up and Down\n',
#   'GET-ATTENTION-IH': None,
#   'GET-ATTENTION-OF': None,
#   'GET-IDEA': 'Up\n',
#   'GET-INTO-BED': 'Sideways\n',
#   'GET-INTO-BED1C': 'Unknown\n',
#   'GET-INTO-BED3': 'Down\n',
#   'GET-LOST2': 'Away\n',
#   'GET-OUT': 'Up\n',
#   'GET-UP': 'Sideways\n',
#   'GIBBERISH': 'Side to Side\n',
#   'GIGGLE': 'Back and Forth\n',
#   'GIGGLE-2H': 'Side to Side\n',
#   'GIRL': 'Unknown\n',
#   'GIRL-BOY': None,
#   'GIRL-FRIEND': 'Unknown\n',
#   'GIRL2': 'Unknown\n',
#   'GIRL2(FALSE START)': 'Unknown\n',
#   'GIRLFRIEND2': 'Down\n',
#   'GIVE': 'Away\n',
#   'GIVE(FLATO)': 'Unknown\n',
#   'GIVE(FLATO)-1H': 'Unknown\n',
#   'GIVE(HCFLAT)': 'Unknown\n',
#   'GIVE(IRISHT)': 'Unknown\n',
#   'GIVE1': 'Unknown\n',
#   'GIVE1(FLATO)': 'Unknown\n',
#   "GLAD-IT'S-OVER": 'Down\n',
#   'GLASS': 'Side to Side\n',
#   'GLASS3': 'Up\n',
#   'GO': 'Away\n',
#   'GO(5)': 'Unknown\n',
#   'GO(5)-2H': 'Away\n',
#   'GO-2H': 'Away\n',
#   'GO-2H(5)': 'Away\n',
#   'GO-BLANK': 'Sideways\n',
#   'GO-BY(1)': 'Down\n',
#   'GO-DOWN': 'Down\n',
#   'GO-DOWN(B)': 'Down\n',
#   'GO-GREAT': 'Sideways\n',
#   'GO-HOME': 'Sideways\n',
#   'GO-HOME-2H': 'Away\n',
#   'GO-IN': 'Down\n',
#   'GO-IN-1H': 'Unknown\n',
#   'GO-ON': 'Away\n',
#   'GO-ON-1H': 'Unknown\n',
#   'GO-OUT': 'Away\n',
#   'GO-OUT(1H)': 'Up\n',
#   'GO-POINT': 'Up\n',
#   'GO-POINT(7)-2H': 'Up\n',
#   'GO-POINT(B)': 'Down\n',
#   'GO-POINT(FALSE-START)': 'Up\n',
#   'GO-POINT(L)-2H': 'Sideways\n',
#   'GO-POINT-2H': 'Away\n',
#   'GO-THERE': 'Sideways\n',
#   'GO-TO': 'Away\n',
#   'GO-TO-AND-FRO': 'Back and Forth\n',
#   'GO-TO-AND-FRO1': 'Side to Side\n',
#   'GO-TO-AND-FRO2': None,
#   'GO-TO-BED': 'Towards\n',
#   'GO-TRACE': 'Sideways\n',
#   'GO-TRACE(2)': 'Sideways\n',
#   'GO-TRACE(B)': 'Sideways\n',
#   'GO-UP': 'Up\n',
#   'GO-UP(B)': 'Up\n',
#   'GO7': 'Side to Side\n',
#   'GONE1': 'Sideways\n',
#   'GONE1-2H': 'Away\n',
#   'GONE1-2H(5)': 'Away\n',
#   'GOOD': 'Unknown\n',
#   'GOOD-2H': 'Unknown\n',
#   'GOOD-2H(7)': 'Unknown\n',
#   'GOT-IDEA': 'Up\n',
#   'GRAB': 'Away\n',
#   'GRAB-2': 'Away\n',
#   'GRAB-2H': 'Back and Forth\n',
#   'GRANDMOTHER': 'Unknown\n',
#   'GRANDMOTHER1': 'Unknown\n',
#   'GRANDMOTHER2': 'Up and Down\n',
#   'GRANDMOTHER2B': 'Down\n',
#   'GRANDMOTHER3': 'Up and Down\n',
#   'GRANDMOTHER3(3)': 'Down\n',
#   'GRASS': 'Sideways\n',
#   'GRASS(4)': 'Away\n',
#   'GRAZE': 'Away\n',
#   'GRAZE-1H': 'Local Movement\n',
#   'GRAZE-2H': 'Local Movement\n',
#   'GREEN': 'Towards\n',
#   'GREEN1': 'Towards\n',
#   'GREY': 'Vertical Circular\n',
#   'GREY1': 'Vertical Circular\n',
#   'GREY3-1H': 'Horizontal Circular\n',
#   'GROUND': 'Sideways\n',
#   'GROUP': 'Local Movement\n',
#   'GROW': 'Up\n',
#   'GROW-1H': 'Up\n',
#   'GRUDGE': 'Unknown\n',
#   'GRUDGE2': None,
#   'GRUMPY': 'Local Movement\n',
#   'GUFFAW': 'Away\n',
#   'GUN(HTHUMB)': 'Local Movement\n',
#   'HAIR': 'Local Movement\n',
#   'HAIR(GO)': 'Unknown\n',
#   'HAIR-BUN': 'Local Movement\n',
#   'HAIR-WASHING': 'Back and Forth\n',
#   'HAIRBRUSH': 'Up and Down\n',
#   'HAIRBRUSH(IRISHT)': 'Back and Forth\n',
#   'HALF': 'Sideways\n',
#   'HALF1': 'Sideways\n',
#   'HALF2': 'Sideways\n',
#   'HAND-1H': 'Local Movement\n',
#   'HAPPEN': 'Up\n',
#   'HAPPEN(2)': 'Up\n',
#   'HAPPY': 'Local Movement\n',
#   'HAPPY1': 'Local Movement\n',
#   'HARD': None,
#   'HARE': 'Local Movement\n',
#   'HAT': 'Unknown\n',
#   'HAT(5)-2H': 'Down\n',
#   'HAT-HEAD1': 'Unknown\n',
#   'HAT-HEAD1A': 'Down\n',
#   'HAVE': None,
#   'HAVE-2H': None,
#   'HAVE-NONE': None,
#   'HAVE-NONE-OF': None,
#   'HAVE-NONE-OF-2H': None,
#   'HAVE-NOT': 'Up\n',
#   'HAVE-NOT-2H': 'Unknown\n',
#   'HEAD': None,
#   'HEAR': 'Local Movement\n',
#   'HEAR2': None,
#   'HEAR2(1)': None,
#   'HEAR2(5)': 'Unknown\n',
#   'HEAR2(B)': None,
#   'HEARING1': None,
#   'HEART-THROB': None,
#   'HEART-THROB-1H': 'Local Movement\n',
#   'HEAVY': None,
#   'HELLO': None,
#   'HELLO1': None,
#   'HELP': None,
#   'HELP1': None,
#   'HI': None,
#   'HIDE1': None,
#   'HIDE1A': 'Unknown\n',
#   'HIGHWAY': 'Side to Side\n',
#   'HILL': None,
#   'HILLS': None,
#   'HOLD': None,
#   'HOLD-2H': 'Local Movement\n',
#   'HOLD-OFFER-BANANA': 'Away\n',
#   'HOLD-ON': 'Away\n',
#   'HOLD-ON(5)': None,
#   'HOLD-ON(B)': None,
#   'HOLD-ON-2H': 'Unknown\n',
#   'HOLE': 'Local Movement\n',
#   'HOLE1': 'Local Movement\n',
#   'HOLE2': None,
#   'HOLE2B': 'Local Movement\n',
#   'HOME': None,
#   'HOME-2H': None,
#   'HONEY': None,
#   'HOPE': None,
#   'HORNS': None,
#   'HORRIBLE': None,
#   'HORSE': None,
#   'HOT': 'Away\n',
#   'HOT(FALSE START)': None,
#   'HOT-2H': 'Away\n',
#   'HOUR': None,
#   'HOUR1': None,
#   'HOUSE': None,
#   'HOUSE(2)': 'Unknown\n',
#   'HOUSE(H)': 'Down\n',
#   'HOW': None,
#   'HOW-MANY': None,
#   'HOW1': None,
#   'HOW2': None,
#   'HUG': None,
#   'HUNGRY': 'Local Movement\n',
#   'HURRY': None,
#   'HURRY(H)': 'Down\n',
#   'HURT': None,
#   'IDEA': 'Away\n',
#   'IF': None,
#   'IGNORE': 'Down\n',
#   'IMAGINE3': 'Sideways\n',
#   'IMPOSSIBLE': None,
#   'IN': None,
#   'IN(2)': None,
#   'IN(FALSE-START)': None,
#   'IN(H)-1H': None,
#   'IN-1H': None,
#   'IN-CASE': None,
#   'INCECIPHERABLE': None,
#   'INCREDIBLE': None,
#   'INDECIPERABLE': 'Unknown\n',
#   'INDECIPHERABLE': None,
#   'INDECIPHERABLE(FALSE-START)': None,
#   'INDETERMINATE': None,
#   'INFORM': None,
#   'INFORM(B)': None,
#   'INSERT-COIN': 'Local Movement\n',
#   'INSIDE': None,
#   'INSIDE(FLATO)': None,
#   'INSIDE-1H': 'Unknown\n',
#   'INSTANT': None,
#   'INTEND2': None,
#   'INTEND2(F)': None,
#   'INTEREST': None,
#   'INTERESTED': None,
#   'INTERESTING': None,
#   'INTERMITTENT': None,
#   'INTERRUPT': None,
#   'INTERSECT': None,
#   'INTUITION': 'Unknown\n',
#   'INVENT': None,
#   'INVENT2': 'Up\n',
#   'IRRITATED': None,
#   'ISLAND1': None,
#   'IT(SE)': None,
#   'ITCH': 'Back and Forth\n',
#   'JACKET1(F)': None,
#   'JAR': None,
#   'JOIN2': 'Local Movement\n',
#   'JOKE': 'Away\n',
#   'JOKE-1H': None,
#   'JOKE-2': None,
#   'JOKE-2H': None,
#   'JOKE1-2H': 'Away\n',
#   'JOKE1-2H(FALSE-START)': None,
#   'JUMP': 'Up\n',
#   'JUMP-OFF': 'Up and Down\n',
#   'JUMP-UP': 'Up\n',
#   'JUMP-UP(P)': 'Up\n',
#   'JUMP-UP(variants)': 'Up\n',
#   'JUMPER': 'Down\n',
#   'JUST(SE)': None,
#   'JUST-FOR-FUN': 'Down\n',
#   'KANGAROO': 'Up and Down\n',
#   'KEEN': 'Back and Forth\n',
#   'KEEN(BENT8)': None,
#   'KEEP': 'Sideways\n',
#   'KICK': 'Up and Down\n',
#   'KILL': None,
#   'KILL-X': 'Away\n',
#   'KISS': None,
#   'KNEEL': 'Down\n',
#   'KNIFE': None,
#   'KNIFE(H)': 'Down\n',
#   'KNOCK-1H': 'Local Movement\n',
#   'KNOW': None,
#   'KNOW(7)': None,
#   'KNOW-NOT': None,
#   'KNOW-NOT-2H': None,
#   'KNOW-YOU': 'Away\n',
#   'KNOW-YOU(CHEEK)': None,
#   'LAB7': None,
#   'LADY': 'Down\n',
#   'LADY1': None,
#   'LADY1(FALSE START)': None,
#   'LADY2': None,
#   'LARGE': 'Sideways\n',
#   'LARGE-HEAP': None,
#   'LAST': None,
#   'LAST-THREE-YEAR': 'Down\n',
#   'LATE': None,
#   'LATER': None,
#   'LATER(B)': 'Sideways\n',
#   'LAUGH': 'Side to Side\n',
#   'LAUGH(BC)': 'Side to Side\n',
#   'LAUGH-1H': None,
#   'LAUGH-AT': None,
#   'LEAF': None,
#   'LEAP-INTO-THE-AIR': 'Up\n',
#   'LEARN': None,
#   'LEARN-MY-LESSON': 'Away\n',
#   'LEARN2': 'Towards\n',
#   'LEARNT': None,
#   'LEAVING': 'Unknown\n',
#   'LEFT-SIDE': None,
#   'LEG': None,
#   'LENGTH': 'Away\n',
#   'LESS': 'Sideways\n',
#   'LESS(BENTB)': None,
#   "LET'S-SEE": None,
#   'LETS-SEE': None,
#   'LETTER': None,
#   'LIAR': 'Sideways\n',
#   'LICK': None,
#   'LICK-CHEEK': None,
#   'LICK-LOCATED': None,
#   'LICK-ON-FACE': None,
#   'LICK1A': 'Up\n',
#   'LID(SE)': 'Local Movement\n',
#   'LIE': None,
#   'LIE-DOWN': None,
#   'LIE-DOWN(BENT2)': 'Down\n',
#   'LIFE': None,
#   'LIGHT2': None,
#   'LIKE': None,
#   'LIKE1': None,
#   'LIKE2': 'Unknown\n',
#   'LIKE2-1H': None,
#   'LINE': 'Sideways\n',
#   'LINE(ASL)': 'Sideways\n',
#   'LINE-UP': 'Sideways\n',
#   'LINES': 'Sideways\n',
#   'LINES(1)': 'Sideways\n',
#   'LINES(FALSE-START)': None,
#   'LITTLE': None,
#   'LITTLE1B': None,
#   'LITTLE2': None,
#   'LIVE': None,
#   'LIVE-2H': None,
#   'LIVE2-2H': None,
#   'Loc': 'Down\n',
#   'LOG': 'Vertical Circular\n',
#   'LOLLY': 'Local Movement\n',
#   'LONG': None,
#   'LONG-AGO': 'Unknown\n',
#   'LONG-HAIR': 'Down\n',
#   ...},
#  0)

# %% [markdown]
# ## Primary Movement KeyBind.txt -> int

# %%
label_keys = {"Up\n":0, "Down\n":1, "Up and Down\n":2, "Sideways\n":3, 
              "Side to Side\n":4, "Away\n":5, "Towards\n":6, 
              "Back and Forth\n":7, "Horizontal Circular\n":8, 
              "Vertical Circular\n":9, "Local Movement\n":10, "Unknown\n": 11,}
label_keys
# Out:
# {'Up\n': 0,
#  'Down\n': 1,
#  'Up and Down\n': 2,
#  'Sideways\n': 3,
#  'Side to Side\n': 4,
#  'Away\n': 5,
#  'Towards\n': 6,
#  'Back and Forth\n': 7,
#  'Horizontal Circular\n': 8,
#  'Vertical Circular\n': 9,
#  'Local Movement\n': 10,
#  'Unknown\n': 11}

# %% [markdown]
# # Load in the imputed dataset

# %%
X = []
Y = []
title = []
videoWord = []
coorDataLocation = "D:/Thesis/ELAR-Data/imputedArrayData/"
dirData = os.listdir(coorDataLocation)
for i, data in enumerate(dirData):
    if i % 2:
        continue
    coorLoad = np.loadtxt(coorDataLocation + data)
    coorShape= np.loadtxt(coorDataLocation + dirData[i + 1])
    
    try:
        coorLoad = coorLoad.reshape(coorLoad.shape[0], coorLoad.shape[1] // int(coorShape[2]), int(coorShape[2]))
    except:
        print(data, dirData[i + 1], coorLoad.shape, coorShape.shape)
    title.append(data)
    X.append(coorLoad)
len(X)
# Out:
# 14058

# %% [markdown]
# #### Remove the .npy and replace .mp4

# %%
newTitle = []

for name in title:
    newName = name[:-4] + '.mp4'
    newTitle.append(newName)
title = np.array(newTitle)
len(title)
# Out:
# 14058

# %% [markdown]
# #### Save OriginalX values

# %%
originalX = X
originalTitle = title
len(originalX)
# Out:
# 14058

# %% [markdown]
# #### In case error ocured reload in x

# %%
X = originalX
title = originalTitle
len(X)
# Out:
# 14058

# %% [markdown]
# ## Load in usability

# %%
usability = {}

f = open("useability.txt", "r")
line = f.readline()
while (line):
    try:
        if line.split("_|_")[1] == 'None\n':
            usability[line.split("_|_")[0]] = None
        else:
            usability[line.split("_|_")[0]] = int(line.split("_|_")[1])
    except:
        if line != '\n':
            print(line)
    line = f.readline()
f.close()

numUsablility = {0:0,1:0,2:0,3:0,4:0}
for key, value in usability.items():
    numUsablility[value] += 1
len(usability), numUsablility
# Out:
# (16784, {0: 2882, 1: 3014, 2: 5088, 3: 5467, 4: 333})

# %% [markdown]
# # Load in the classifications

# %%
saveLocation = "D:/Thesis/Video-Auslan-sorted"
pathMovement = {}
for word in os.listdir(saveLocation):
    pathMovement[word] = None
    
f = open("keyBinds.txt", "r")
line = f.readline()
i= 0
j = 0
while (line):
    try:
        if line.split("_|_")[1] == 'None\n':
            pathMovement[line.split("_|_")[0].upper()] = None
        else:
            pathMovement[line.split("_|_")[0].upper()] = line.split("_|_")[1]
    except:
        i += 1
    line = f.readline()
f.close()
pathMovement
# Out:
# {'ABOUT1': 'Vertical Circular\n',
#  'ABOUT2': 'Vertical Circular\n',
#  'ABOUT2(7)': 'Vertical Circular\n',
#  'ABOUT2(B)': None,
#  'ABOUT2(FALSE-START)': 'Unknown\n',
#  'ACCEPT': 'Towards\n',
#  'ACCOMMODATION-2H': 'Back and Forth\n',
#  'ACCURATE': 'Up and Down\n',
#  'ACHIEVE': 'Away\n',
#  'ACTIVITY-THERE': 'Sideways\n',
#  'ADULT': 'Horizontal Circular\n',
#  'AFRAID': 'Back and Forth\n',
#  'AFTERNOON': 'Local Movement\n',
#  'AFTERNOON3': 'Towards\n',
#  'AFTERNOON4': 'Towards\n',
#  'AGAIN': 'Down\n',
#  'AGAIN(8)': None,
#  'AGAIN-2H': 'Local Movement\n',
#  'AGAIN-AND-AGAIN': 'Up and Down\n',
#  'AGES': 'Horizontal Circular\n',
#  'AGREE': 'Sideways\n',
#  'AIM': 'Unknown\n',
#  'ALIVE': 'Towards\n',
#  'ALL': 'Horizontal Circular\n',
#  'ALL-2H': 'Away\n',
#  'ALL-DAY': 'Up\n',
#  'ALL-DAY-2H': 'Horizontal Circular\n',
#  'ALL-DAY-LONG': 'Vertical Circular\n',
#  'ALLOW': 'Local Movement\n',
#  'ALMOST': 'Unknown\n',
#  'ALMOST(FLATGO)': None,
#  'ALMOST-2H': 'Unknown\n',
#  'ALRIGHT': 'Unknown\n',
#  'ALRIGHT-2H': 'Unknown\n',
#  'ALRIGHT2': 'Local Movement\n',
#  'ALWAYS': 'Away\n',
#  'ALWAYS1': 'Away\n',
#  'ALWAYS2': 'Up\n',
#  'AMERINDIAN': 'Local Movement\n',
#  'AMERINDIAN(FALSE START)': 'Up\n',
#  'AMERINDIAN2': 'Up\n',
#  'AMERINDIAN2(FALSE START)': 'Unknown\n',
#  'AND-THEN': 'Local Movement\n',
#  'AND1': 'Away\n',
#  'ANGRY': 'Unknown\n',
#  'ANGRY-2H': 'Up\n',
#  'ANGRY1': 'Up and Down\n',
#  'ANGRY1-2H': 'Up\n',
#  'ANIMAL': 'Vertical Circular\n',
#  'ANNOUNCE': 'Back and Forth\n',
#  'ANNOYED': 'Up\n',
#  'ANOTHER': 'Unknown\n',
#  'ANSWER': 'Down\n',
#  'APOSTROPHE': 'Unknown\n',
#  'APPROACH': 'Unknown\n',
#  'APPROACH-CLOSE': 'Towards\n',
#  'AREA': 'Horizontal Circular\n',
#  'AREA-2H': 'Horizontal Circular\n',
#  'ARGUE': 'Up and Down\n',
#  'ARM(5)': 'Unknown\n',
#  'AROUND': 'Horizontal Circular\n',
#  'AROUND-1H(R-VERT)': None,
#  'ARRIVE': 'Up and Down\n',
#  'ARRIVE(FALSE-START)': 'Unknown\n',
#  'ARRIVE(IRISHK)-1H': 'Unknown\n',
#  'ASK': 'Unknown\n',
#  'AT-HEART': 'Local Movement\n',
#  'ATTACK': 'Away\n',
#  'ATTEND': 'Sideways\n',
#  'ATTEND2': 'Unknown\n',
#  'ATTENTION': 'Unknown\n',
#  'ATTENTION2': 'Unknown\n',
#  'ATTRACT': 'Unknown\n',
#  'AVERAGE': 'Sideways\n',
#  'AWAY': 'Away\n',
#  'AWKWARD': 'Side to Side\n',
#  'B(FALSE-START)': 'Unknown\n',
#  'BABY': 'Side to Side\n',
#  'BACK': 'Towards\n',
#  'BACK(1)': 'Towards\n',
#  'BACK-HEAD': 'Unknown\n',
#  'BACK-SHOULDER': 'Local Movement\n',
#  'BACK2': 'Unknown\n',
#  'BAD': 'Local Movement\n',
#  'BAD(Y)': 'Local Movement\n',
#  'BAD-2H': 'Local Movement\n',
#  'BAD-LUCK': 'Local Movement\n',
#  'BALANCE': 'Up and Down\n',
#  'BALL': 'Unknown\n',
#  'BALL1': 'Local Movement\n',
#  'BALL1(5)': 'Local Movement\n',
#  'BALL1(B)': 'Local Movement\n',
#  'BALL1-1H': 'Unknown\n',
#  'BALL2': 'Local Movement\n',
#  'BALL2-1H': 'Unknown\n',
#  'BALL3': 'Unknown\n',
#  'BAN': 'Unknown\n',
#  'BAN(1)': 'Unknown\n',
#  'BANANA1': 'Local Movement\n',
#  'BANANA2': 'Sideways\n',
#  'BARK': 'Local Movement\n',
#  'BASIN': 'Away\n',
#  'BATH': 'Up and Down\n',
#  'BATH(B)': 'Down\n',
#  'BATH(B)-H1': 'Up and Down\n',
#  'BEAT': 'Local Movement\n',
#  'BEAUTIFUL': 'Unknown\n',
#  'BEAUTIFUL(SE)': 'Unknown\n',
#  'BECAUSE1': 'Unknown\n',
#  'BECAUSE2': 'Unknown\n',
#  'BECAUSE3': 'Unknown\n',
#  'BECKON2': 'Local Movement\n',
#  'BECKON2-2H': 'Local Movement\n',
#  'BECOME': 'Up and Down\n',
#  'BECOME(IRISHT)': 'Vertical Circular\n',
#  'BECOME1B(IRISHT)': 'Up and Down\n',
#  'BED': 'Unknown\n',
#  'BED-2H': 'Unknown\n',
#  'BED1': 'Unknown\n',
#  'BED2': 'Down\n',
#  'BED2-2H': 'Unknown\n',
#  'BEDFRAME': None,
#  'BEDROOM2': 'Unknown\n',
#  'BEE': 'Unknown\n',
#  'BEE(FLATO)': 'Up\n',
#  'BEE(IRISHK)': 'Unknown\n',
#  'BEE-2H': None,
#  'BEFORE-THAT': 'Towards\n',
#  'BEFORE-THAT(1)': 'Towards\n',
#  'BEFORE-THAT(1)-1H': 'Towards\n',
#  'BEFORE1': 'Local Movement\n',
#  'BEFORE1(FALSE-START)': 'Unknown\n',
#  'BEFORE2': None,
#  'BEG3': 'Unknown\n',
#  'BEGIN': 'Down\n',
#  'BEGIN(FALSE-START)': 'Unknown\n',
#  'BEGIN(HTHUMB)-1H': 'Down\n',
#  'BEGIN-1H': 'Down\n',
#  'BELIEVE': 'Local Movement\n',
#  'BELIEVE-NOT2': 'Away\n',
#  'BELIEVE2': 'Down\n',
#  'BELIEVE2(FALSE-START)': 'Unknown\n',
#  'BELIEVE2-NOT': 'Away\n',
#  'BELONG2': 'Unknown\n',
#  'BESIDE': 'Local Movement\n',
#  'BEST': 'Unknown\n',
#  'BET': 'Back and Forth\n',
#  'BET1': 'Back and Forth\n',
#  'BET1(B)': 'Unknown\n',
#  'BETTER': 'Local Movement\n',
#  'BIG': 'Sideways\n',
#  'BIG(BENT7)': 'Unknown\n',
#  'BIG-CHEST': None,
#  'BIG1': 'Sideways\n',
#  'BIG2': 'Sideways\n',
#  'BIG3': 'Unknown\n',
#  'BIRD': 'Local Movement\n',
#  'BIRD(FALSE-START)': 'Unknown\n',
#  'BIRTH': 'Side to Side\n',
#  'BISCUIT': 'Local Movement\n',
#  'BIT': 'Unknown\n',
#  'BITE': 'Towards\n',
#  'BITE-2H': 'Away\n',
#  'BITE1': 'Towards\n',
#  'BLACK': 'Down\n',
#  'BLACK2': 'Unknown\n',
#  'BLANK': 'Horizontal Circular\n',
#  'BLANK-1H': 'Unknown\n',
#  'BLANKET': 'Towards\n',
#  'BLAST': 'Unknown\n',
#  'BLAZING-SUN': 'Local Movement\n',
#  'BLESS-YOU': 'Local Movement\n',
#  'BLOCK': 'Unknown\n',
#  'BLOCK(BC)': 'Away\n',
#  'BLOCK2': 'Unknown\n',
#  'BLOOD': None,
#  'BLUR': 'Sideways\n',
#  'BODY': 'Unknown\n',
#  'BOOK': 'Local Movement\n',
#  'BOOK-OPEN': None,
#  'BOOT': 'Local Movement\n',
#  'BOOTS': 'Local Movement\n',
#  'BORED': 'Sideways\n',
#  'BORING': 'Sideways\n',
#  'BORING1': 'Sideways\n',
#  'BORING2': 'Back and Forth\n',
#  'BORN1': None,
#  'BORN2': None,
#  'BOTH': 'Side to Side\n',
#  'BOTH-2H': None,
#  'BOTH1': 'Local Movement\n',
#  'BOTHER': 'Unknown\n',
#  'BOTHER(S)': 'Local Movement\n',
#  'BOTHER(S)-1H': None,
#  'BOTHER-NOT': 'Away\n',
#  'BOTTOM': 'Down\n',
#  'BOTTOM2': None,
#  'BOW': 'Down\n',
#  'BOW-TIE1': 'Sideways\n',
#  'BOWL': 'Unknown\n',
#  'BOWLING': 'Away\n',
#  'BOX': 'Unknown\n',
#  'BOY': 'Side to Side\n',
#  'BOY(BENT2)': None,
#  'BOY(FALSE START)': 'Unknown\n',
#  'BOY(FALSE-START)': 'Unknown\n',
#  'BOY1': 'Side to Side\n',
#  'BOY1(FALSE-START)': 'Unknown\n',
#  'BOY1(IRISHH)': 'Unknown\n',
#  'BOY1(P)': 'Sideways\n',
#  'BOY2': 'Unknown\n',
#  'BREAK': 'Sideways\n',
#  'BREAK(5)': 'Local Movement\n',
#  'BREAK-5': 'Unknown\n',
#  'BREAK-WIND-2H': 'Side to Side\n',
#  'BREAK2': 'Sideways\n',
#  'BREATHE': 'Back and Forth\n',
#  'BREATHE-2H': 'Back and Forth\n',
#  'BRICK': 'Unknown\n',
#  'BRICK2': 'Up\n',
#  'BRICK2(BC)': 'Up and Down\n',
#  'BRICKLAYER': 'Up\n',
#  'BRICKLAYER(6)': 'Back and Forth\n',
#  'BRICKLAYER(B)': 'Back and Forth\n',
#  'BRICKLAYER(IRISHT)': 'Side to Side\n',
#  'BRIDGE': 'Sideways\n',
#  'BRIDGE(FALSE START)': 'Unknown\n',
#  'BRIDGE-1H': 'Sideways\n',
#  'BRIDGE2': 'Sideways\n',
#  'BRING': 'Sideways\n',
#  'BROWN1': 'Local Movement\n',
#  'BRUSH': 'Down\n',
#  'BRUSH(FALSE START)': 'Unknown\n',
#  'BRUSH-2H': 'Down\n',
#  'BUILD': 'Up and Down\n',
#  'BUILD(H)': 'Up and Down\n',
#  'BUILD1A': 'Up and Down\n',
#  'BUILD1B': 'Up and Down\n',
#  'BUILDING': 'Up and Down\n',
#  'BUILDING-H': 'Up and Down\n',
#  'BULLSHIT': None,
#  'BULLSHIT2-2H': 'Down\n',
#  'BUN-HAIR': 'Unknown\n',
#  'BURROW(B)': 'Side to Side\n',
#  'BURST': 'Side to Side\n',
#  'BUSH': 'Vertical Circular\n',
#  'BUSINESS': 'Towards\n',
#  'BUSY': 'Back and Forth\n',
#  'BUT2': 'Unknown\n',
#  'BYE': 'Side to Side\n',
#  'CAKE': 'Up and Down\n',
#  'CAKE(IRISHK)': 'Up and Down\n',
#  'CALCULATE': 'Down\n',
#  'CALL': None,
#  'CALL2': 'Away\n',
#  'CALLED': 'Down\n',
#  'CALM': 'Down\n',
#  'CAMERA2': 'Local Movement\n',
#  'CAN': 'Away\n',
#  'CAN(FALSE-START)': 'Unknown\n',
#  'CAN-NOT': 'Sideways\n',
#  'CAN-NOT-2H': 'Sideways\n',
#  'CANNOT': 'Sideways\n',
#  'CAPTURE2': 'Unknown\n',
#  'CAPTURE2-1H': None,
#  'CAR': 'Horizontal Circular\n',
#  'CAR-1H': 'Horizontal Circular\n',
#  'CAR2': 'Up and Down\n',
#  'CAR2-1H': 'Unknown\n',
#  'CARE': 'Down\n',
#  'CARE-NOT': 'Away\n',
#  'CARELESS(1)': 'Away\n',
#  'CARTOON': 'Back and Forth\n',
#  'CARTOON-CHEEK': None,
#  'CAT': 'Side to Side\n',
#  'CAT(FLATBC)': 'Side to Side\n',
#  'CAT-1H': 'Unknown\n',
#  'CAT1': 'Unknown\n',
#  'CAT1(FALSE START)': 'Unknown\n',
#  'CAT2': 'Side to Side\n',
#  'CAT2(12)': 'Side to Side\n',
#  'CAT2(F)': 'Unknown\n',
#  'CAT2(FBC)': 'Unknown\n',
#  'CAT2(HTHUMB)': 'Unknown\n',
#  'CAT2(P)': 'Unknown\n',
#  'CAT2(X)': 'Unknown\n',
#  'CAT2-1H': 'Sideways\n',
#  'CAT2-2H': 'Unknown\n',
#  'CAT2-H': 'Unknown\n',
#  'CATCH': 'Horizontal Circular\n',
#  'CATCH(FALSE-START)': 'Unknown\n',
#  'CATCH-1H': 'Unknown\n',
#  'CATCH-2H': 'Down\n',
#  'CATCH-UP-WITH': 'Unknown\n',
#  'CATTLE': 'Up\n',
#  'CATTLE(FALSE-START)': None,
#  'CAUGHT-BY-SURPRISE': 'Towards\n',
#  'CEILING': 'Away\n',
#  'CEILING-2H': 'Away\n',
#  'CENTRE': 'Local Movement\n',
#  'CENTRE-1H': 'Unknown\n',
#  'CHAIR': 'Down\n',
#  'CHAIR(B)': 'Down\n',
#  'CHAIR(BENTB)': 'Down\n',
#  'CHAIR1(SE)': 'Down\n',
#  'CHAIR2': 'Down\n',
#  'CHAIR2(BENTB)': 'Down\n',
#  'CHALLENGE': 'Unknown\n',
#  'CHANGE': 'Sideways\n',
#  'CHANGE(B)': 'Unknown\n',
#  'CHANGE-MIND(NEUTRAL-SPACE)': 'Unknown\n',
#  'CHANGE1(IRISHT)': None,
#  'CHANGE2': 'Unknown\n',
#  'CHASE': 'Away\n',
#  'CHASE-1H': 'Unknown\n',
#  'CHASE2': 'Vertical Circular\n',
#  'CHATTERBOX': 'Away\n',
#  'CHECK2': 'Unknown\n',
#  'CHEEKY': 'Unknown\n',
#  'CHEESE3': 'Side to Side\n',
#  'CHERISH': 'Up and Down\n',
#  'CHERISH-1H': None,
#  'CHERISH1': 'Up and Down\n',
#  'CHEW': 'Side to Side\n',
#  'CHILD': 'Down\n',
#  'CHILDREN': 'Sideways\n',
#  'CHILDREN1-2H': 'Sideways\n',
#  'CHILDREN2-2H': 'Sideways\n',
#  'CHOOSE': None,
#  'CIRCLE': 'Vertical Circular\n',
#  'CITY': 'Up and Down\n',
#  'CLEAN': 'Back and Forth\n',
#  'CLEAN3': 'Vertical Circular\n',
#  'CLEAN3B': 'Horizontal Circular\n',
#  'CLEAR': 'Sideways\n',
#  'CLEVER': 'Sideways\n',
#  'CLIFF': 'Down\n',
#  'CLIFF(FALSE-START)': None,
#  'CLIFF-2H': 'Down\n',
#  'CLIMB': 'Up and Down\n',
#  'CLIMB-1H': 'Unknown\n',
#  'CLIMB1': 'Sideways\n',
#  'CLIMB2': 'Unknown\n',
#  'CLIMB3': 'Unknown\n',
#  'CLOSE(FALSE START)': 'Unknown\n',
#  'CLOSE-SHUT': 'Down\n',
#  'CLOTHES': 'Up and Down\n',
#  'CLOTHES1': 'Up and Down\n',
#  'CLUB': 'Up and Down\n',
#  'COAT': 'Sideways\n',
#  'COAT(BENTB)': 'Sideways\n',
#  'COAT(IRISHT)': 'Sideways\n',
#  'COFFEE': 'Unknown\n',
#  'COINCIDENCE': 'Up and Down\n',
#  'COLD': 'Side to Side\n',
#  'COLD(FALSE-START)': 'Unknown\n',
#  'COLLECT': 'Unknown\n',
#  'COLLECT1A': 'Unknown\n',
#  'COLLECT2': 'Unknown\n',
#  'COLLECT2-1H': 'Unknown\n',
#  'COMB': 'Up and Down\n',
#  'COME': 'Towards\n',
#  'COME(BENTB)': 'Unknown\n',
#  'COME-2H': 'Towards\n',
#  'COME-ON': 'Up and Down\n',
#  'COMMON': None,
#  'COMMUNICATE': 'Back and Forth\n',
#  'COMMUNITY': 'Sideways\n',
#  'COMPETE': 'Sideways\n',
#  'COMPLETE': 'Away\n',
#  'CONFIRM': 'Up and Down\n',
#  'CONSIDER': 'Vertical Circular\n',
#  'CONSIDER-2H': 'Unknown\n',
#  'CONSIDER-2H(CG)': 'Vertical Circular\n',
#  'CONSIDER1B': 'Vertical Circular\n',
#  'CONSIDER1C': 'Unknown\n',
#  'CONTINUE': 'Up and Down\n',
#  'CONTINUE(1)': 'Up and Down\n',
#  'CONTINUE-1H': 'Up and Down\n',
#  'CONTROL': 'Back and Forth\n',
#  'COOL': 'Unknown\n',
#  'CORN': 'Unknown\n',
#  'CORN1-2H': 'Unknown\n',
#  'CORN3': 'Unknown\n',
#  'CORNER': 'Sideways\n',
#  'COUNTRY': 'Unknown\n',
#  'COW': 'Up\n',
#  'COW(FALSE-START)': 'Unknown\n',
#  'COWBOY': 'Up and Down\n',
#  'COWBOY(1)': 'Up and Down\n',
#  'COWBOY(2)': 'Up and Down\n',
#  'COWBOY(HTHUMB)': 'Up and Down\n',
#  'CRANKY': 'Unknown\n',
#  'CRAZY1': None,
#  'CREEK(2)': None,
#  'CRIED': 'Unknown\n',
#  'CROWD': 'Unknown\n',
#  'CRY': 'Up and Down\n',
#  'CRY-1H': 'Up and Down\n',
#  'CRY1': 'Down\n',
#  'CUDDLE': 'Towards\n',
#  'CURIOUS': 'Vertical Circular\n',
#  'CUT-STOP': None,
#  'CUTE': 'Unknown\n',
#  'DAMAGE': 'Away\n',
#  'DAMN': 'Unknown\n',
#  'DAMN2': 'Away\n',
#  'DANCE1': 'Up and Down\n',
#  'DANGER': 'Back and Forth\n',
#  'DANGER1': 'Back and Forth\n',
#  'DANGER2': 'Up and Down\n',
#  'DARE': 'Up\n',
#  'DARE1': 'Unknown\n',
#  'DARK': 'Unknown\n',
#  'DASH-OFF': 'Sideways\n',
#  'DAY': 'Sideways\n',
#  'DAY-1H': 'Sideways\n',
#  'DAYBREAK': None,
#  'DEAD': None,
#  'DEAD(B)': 'Unknown\n',
#  'DEAL-CARDS': 'Back and Forth\n',
#  'DECEIVE': 'Away\n',
#  'DECIDE': 'Down\n',
#  'DECIDE2': 'Unknown\n',
#  'DEEP': 'Down\n',
#  'DEER': 'Away\n',
#  'DEER(4)': 'Away\n',
#  'DEER(FALSE-START)': 'Unknown\n',
#  'DEER(Y)': 'Unknown\n',
#  'DEER-Y': 'Unknown\n',
#  'DEFEAT1': 'Down\n',
#  'DEFEAT2': 'Down\n',
#  'DELAY': None,
#  'DELICIOUS': 'Unknown\n',
#  'DELICIOUS3': 'Unknown\n',
#  'DEMAND': 'Back and Forth\n',
#  'DEPRESS': 'Down\n',
#  'DEPRESSED': 'Down\n',
#  'DEPTH': 'Down\n',
#  'DESPONDENT': 'Down\n',
#  'DETERMINATE': None,
#  'DETERMINED': 'Unknown\n',
#  'DETERMINED2': None,
#  'DIE': 'Unknown\n',
#  'DIE1': 'Away\n',
#  'DIFFERENT': 'Sideways\n',
#  'DIFFICULT2': 'Unknown\n',
#  'DIMINISH': 'Unknown\n',
#  'DINNER': 'Up and Down\n',
#  'DINNER(FALSE-START)': 'Unknown\n',
#  'DISAPPEAR': 'Sideways\n',
#  'DISAPPEAR(FALSE-START)': 'Unknown\n',
#  'DISAPPEAR1': 'Sideways\n',
#  'DISAPPEAR2': 'Away\n',
#  'DISAPPEAR2(O)': None,
#  'DISAPPEAR2-2H': None,
#  'DISAPPEAR3': 'Away\n',
#  'DISAPPEAR3B+4': 'Away\n',
#  'DISAPPOINTED': 'Unknown\n',
#  'DISCIPLINE': 'Up and Down\n',
#  'DISCUSS1': 'Unknown\n',
#  'DISPERSE': 'Away\n',
#  'DISTINGUISHED': 'Side to Side\n',
#  'DIZZY': 'Vertical Circular\n',
#  'DO': 'Unknown\n',
#  'DO-SE': None,
#  'DO-THERE': 'Unknown\n',
#  'DO-THERE-2H': 'Unknown\n',
#  'DOCUMENT': 'Down\n',
#  'DOG': 'Up and Down\n',
#  'DOG(FALSE START)': 'Unknown\n',
#  'DOG(FALSE-START)': 'Unknown\n',
#  'DOG-2H': 'Unknown\n',
#  'DOG1': 'Down\n',
#  'DOG2': 'Unknown\n',
#  'DOG2(FALSE-START)': 'Unknown\n',
#  'DOG2-2H': 'Unknown\n',
#  'DOLLAR1': 'Sideways\n',
#  "DON'T": 'Unknown\n',
#  "DON'T-KNOW": 'Unknown\n',
#  "DON'T1-2H": None,
#  'DONE(SE)': None,
#  'DOOR': 'Unknown\n',
#  'DOOR(FALSE START)': 'Away\n',
#  'DOOR-OPEN': 'Towards\n',
#  'DOUBT': 'Up and Down\n',
#  'DOUBT(5)': 'Up and Down\n',
#  'DOUBT-2h': None,
#  'DOWN-B': 'Down\n',
#  'DRAW-ATTENTION': 'Unknown\n',
#  'DRAW-LINE': 'Horizontal Circular\n',
#  'DREAM': None,
#  'DRESS': 'Up and Down\n',
#  'DRESS1C': 'Unknown\n',
#  'DRINK': None,
#  'DRIVE': 'Away\n',
#  'DROP': 'Down\n',
#  'DROP-2H': 'Down\n',
#  'DROP1': 'Down\n',
#  'DRY': None,
#  'DSM(1-VERT)ENTITY-UP-OVER-THERE': 'Up\n',
#  'DSM(2-DOWN)ANIMAL-RUNS': 'Unknown\n',
#  'DSM(BENT2);REACHING-HIGH-POINT': 'Unknown\n',
#  'DULL': 'Sideways\n',
#  'DUNNO': 'Unknown\n',
#  'EAGER': 'Back and Forth\n',
#  'EARLY': 'Unknown\n',
#  'EASY': 'Unknown\n',
#  'EAT': 'Towards\n',
#  'EAT(FALSE-START)': 'Unknown\n',
#  'EAT(MID)': 'Towards\n',
#  'EAT-2H': 'Back and Forth\n',
#  'EDUCATE': None,
#  'EDUCATE-1H': 'Away\n',
#  'EIGHT': 'Unknown\n',
#  'ELIMINATE': 'Away\n',
#  'ELIMINATE1': 'Away\n',
#  'EMIT': 'Unknown\n',
#  'EMPTY': 'Away\n',
#  'ENCOURAGE1': 'Sideways\n',
#  'ENCOURAGE1-HERD': 'Sideways\n',
#  'END': 'Away\n',
#  'ENJOY': 'Unknown\n',
#  'ENJOY2': 'Unknown\n',
#  'ENOUGH': 'Up and Down\n',
#  'EQUAL': 'Away\n',
#  'ESCAPE': 'Away\n',
#  'ESCAPE-IRISHH': 'Unknown\n',
#  'EVERY': 'Away\n',
#  'EVERYDAY': 'Unknown\n',
#  'EVERYTHING': 'Unknown\n',
#  'EXCELLENT': 'Away\n',
#  'EXCELLENT(Y)': 'Unknown\n',
#  'EXCITE': 'Up and Down\n',
#  'EXCITED': 'Up and Down\n',
#  'EXCITING': 'Up and Down\n',
#  'EXPENSIVE': 'Unknown\n',
#  'EXPLODE': 'Side to Side\n',
#  'EXPLORE': 'Unknown\n',
#  'EXTINGUISH': None,
#  'EYELASHES': None,
#  'FACE': 'Vertical Circular\n',
#  'FACE1': 'Vertical Circular\n',
#  'FACIAL-EXPRESSION': 'Up and Down\n',
#  'FACING': 'Unknown\n',
#  'FADE': 'Sideways\n',
#  'FAIL': 'Down\n',
#  'FAINT': 'Down\n',
#  'FAIR': 'Back and Forth\n',
#  'FALL': 'Down\n',
#  'FALL-1H': 'Down\n',
#  'FALL-2H': 'Down\n',
#  'FALL-IN-LOVE': 'Unknown\n',
#  'FALSE-START': 'Unknown\n',
#  'FAMILY': 'Unknown\n',
#  'FAMILY(FALSE-START)': 'Unknown\n',
#  'FAMOUS': 'Sideways\n',
#  'FAR': 'Up\n',
#  'FAR(1)': 'Away\n',
#  'FAR-2H': 'Away\n',
#  'FAR2': 'Away\n',
#  'FARM': 'Down\n',
#  'FARM(SE)': None,
#  'FARM1': 'Down\n',
#  'FARM3': 'Sideways\n',
#  'FART': None,
#  'FAST': 'Down\n',
#  'FAST(FALSE-START)': 'Unknown\n',
#  'FAST1': 'Down\n',
#  'FAST2': 'Away\n',
#  'FAT': 'Sideways\n',
#  'FATHER': None,
#  'FAULT': None,
#  'FBUOY': 'Towards\n',
#  'FEAR': None,
#  'FED-UP': None,
#  'FEEL': 'Up\n',
#  'FEEL-2H': 'Up\n',
#  'FEEL-FIT': 'Back and Forth\n',
#  'FENCE': 'Away\n',
#  'FETCH': 'Unknown\n',
#  'FETCH-1H': 'Unknown\n',
#  'FEW': 'Unknown\n',
#  'FEW(FALSE-START)': 'Unknown\n',
#  'FICTION-2H': None,
#  'FIFTEEN': 'Unknown\n',
#  'FIFTH2': 'Unknown\n',
#  'FILL': 'Unknown\n',
#  'FILL-1H': 'Up\n',
#  'FILM2': 'Unknown\n',
#  'FINALLY': 'Unknown\n',
#  'FIND': 'Unknown\n',
#  'FIND(B)': 'Towards\n',
#  'FIND(FALSE-START)': 'Towards\n',
#  'FIND(X)': 'Unknown\n',
#  'FIND-7X': None,
#  'FIND-X': 'Unknown\n',
#  'FIND1': None,
#  'FIND1A(X)': 'Towards\n',
#  'FIND2': 'Unknown\n',
#  'FINE': 'Back and Forth\n',
#  'FINE-2H': 'Unknown\n',
#  'FINGERSPELL': 'Unknown\n',
#  'FINISH-FIVE': None,
#  'FINISH.FIVE': 'Unknown\n',
#  'FINISH.FIVE-1H': 'Unknown\n',
#  'FINISH.GOOD': 'Side to Side\n',
#  'FINISH.GOOD(FALSE-START)': 'Unknown\n',
#  'FINISH.GOOD-2H': 'Unknown\n',
#  'FIRE': 'Up\n',
#  'FIRST': 'Unknown\n',
#  'FIRST-OF-ONE': 'Unknown\n',
#  'FIRST1': 'Unknown\n',
#  'FIRST2': 'Unknown\n',
#  'FIVE': 'Unknown\n',
#  'FLABBERGASTED': 'Down\n',
#  'FLAT': 'Sideways\n',
#  'FLAT-SURFACE': 'Sideways\n',
#  'FLOOR': 'Sideways\n',
#  'FLOWER': 'Sideways\n',
#  'FLOWER(F)': 'Sideways\n',
#  'FLUKE': 'Unknown\n',
#  'FLY': 'Up and Down\n',
#  'FLY1': 'Up and Down\n',
#  'FLY1B': 'Up and Down\n',
#  'FLY2': 'Up and Down\n',
#  'FOLLOW': 'Away\n',
#  'FOLLOW2': 'Away\n',
#  'FOOL': 'Up\n',
#  'FOOTSTEPS(5)': 'Back and Forth\n',
#  'FOOTSTEPS(O)': 'Back and Forth\n',
#  'FOR': 'Down\n',
#  'FOR-A-WHILE': None,
#  'FOR1': 'Unknown\n',
#  'FOR2': 'Unknown\n',
#  'FORBID': 'Sideways\n',
#  'FORCE': 'Towards\n',
#  'FORCE-A-SMILE': 'Up\n',
#  'FORGET': 'Unknown\n',
#  'FORGET2-2H': None,
#  'FORWARD-1H': None,
#  'FOUND-OUT': 'Unknown\n',
#  'FOUND-OUT(FALSE-START)': 'Unknown\n',
#  'FOUR': 'Unknown\n',
#  'FOURTH2': 'Unknown\n',
#  'FREE': 'Unknown\n',
#  'FRIEND': 'Up and Down\n',
#  'FRIGHTENED': 'Towards\n',
#  'FROG': 'Up and Down\n',
#  'FROG2': 'Up and Down\n',
#  'FROM': 'Unknown\n',
#  'FROM1': 'Away\n',
#  'FRONT': 'Back and Forth\n',
#  'FRONT1': 'Towards\n',
#  'FRUSTRATED': None,
#  'FRUSTRATED-1H': 'Vertical Circular\n',
#  'FRUSTRATED2': 'Vertical Circular\n',
#  'FRUSTRATED2-1h': None,
#  'FRUSTRATED2B': 'Towards\n',
#  'FUCK': 'Unknown\n',
#  'FUCK-OFF-ALL': None,
#  'FUCK-YOU': None,
#  'FUCK2': 'Down\n',
#  'FUCK2-1H': 'Unknown\n',
#  'FULL': 'Unknown\n',
#  'FUN': 'Unknown\n',
#  'FUNNY': None,
#  'FUNNY-STRANGE': 'Unknown\n',
#  'FURNITURE2': 'Down\n',
#  'G(CA)': 'Unknown\n',
#  'G(NMS)': None,
#  'GALLOP': 'Unknown\n',
#  'GAME': 'Unknown\n',
#  'GATE-CLOSE(H)': 'Sideways\n',
#  'GATE-OPEN(H)': 'Away\n',
#  'GATHER': None,
#  'GET': 'Towards\n',
#  'GET(SE)': 'Down\n',
#  'GET-ATTENTION': 'Up and Down\n',
#  'GET-ATTENTION-1H': 'Up and Down\n',
#  'GET-ATTENTION-IH': None,
#  'GET-ATTENTION-OF': None,
#  'GET-IDEA': 'Up\n',
#  'GET-INTO-BED': 'Sideways\n',
#  'GET-INTO-BED1C': 'Unknown\n',
#  'GET-INTO-BED3': 'Down\n',
#  'GET-LOST2': 'Away\n',
#  'GET-OUT': 'Up\n',
#  'GET-UP': 'Sideways\n',
#  'GIBBERISH': 'Side to Side\n',
#  'GIGGLE': 'Back and Forth\n',
#  'GIGGLE-2H': 'Side to Side\n',
#  'GIRL': 'Unknown\n',
#  'GIRL-BOY': None,
#  'GIRL-FRIEND': 'Unknown\n',
#  'GIRL2': 'Unknown\n',
#  'GIRL2(FALSE START)': 'Unknown\n',
#  'GIRLFRIEND2': 'Down\n',
#  'GIVE': 'Away\n',
#  'GIVE(FLATO)': 'Unknown\n',
#  'GIVE(FLATO)-1H': 'Unknown\n',
#  'GIVE(HCFLAT)': 'Unknown\n',
#  'GIVE(IRISHT)': 'Unknown\n',
#  'GIVE1': 'Unknown\n',
#  'GIVE1(FLATO)': 'Unknown\n',
#  "GLAD-IT'S-OVER": 'Down\n',
#  'GLASS': 'Side to Side\n',
#  'GLASS3': 'Up\n',
#  'GO': 'Away\n',
#  'GO(5)': 'Unknown\n',
#  'GO(5)-2H': 'Away\n',
#  'GO-2H': 'Away\n',
#  'GO-2H(5)': 'Away\n',
#  'GO-BLANK': 'Sideways\n',
#  'GO-BY(1)': 'Down\n',
#  'GO-DOWN': 'Down\n',
#  'GO-DOWN(B)': 'Down\n',
#  'GO-GREAT': 'Sideways\n',
#  'GO-HOME': 'Sideways\n',
#  'GO-HOME-2H': 'Away\n',
#  'GO-IN': 'Down\n',
#  'GO-IN-1H': 'Unknown\n',
#  'GO-ON': 'Away\n',
#  'GO-ON-1H': 'Unknown\n',
#  'GO-OUT': 'Away\n',
#  'GO-OUT(1H)': 'Up\n',
#  'GO-POINT': 'Up\n',
#  'GO-POINT(7)-2H': 'Up\n',
#  'GO-POINT(B)': 'Down\n',
#  'GO-POINT(FALSE-START)': 'Up\n',
#  'GO-POINT(L)-2H': 'Sideways\n',
#  'GO-POINT-2H': 'Away\n',
#  'GO-THERE': 'Sideways\n',
#  'GO-TO': 'Away\n',
#  'GO-TO-AND-FRO': 'Back and Forth\n',
#  'GO-TO-AND-FRO1': 'Side to Side\n',
#  'GO-TO-AND-FRO2': None,
#  'GO-TO-BED': 'Towards\n',
#  'GO-TRACE': 'Sideways\n',
#  'GO-TRACE(2)': 'Sideways\n',
#  'GO-TRACE(B)': 'Sideways\n',
#  'GO-UP': 'Up\n',
#  'GO-UP(B)': 'Up\n',
#  'GO7': 'Side to Side\n',
#  'GONE1': 'Sideways\n',
#  'GONE1-2H': 'Away\n',
#  'GONE1-2H(5)': 'Away\n',
#  'GOOD': 'Unknown\n',
#  'GOOD-2H': 'Unknown\n',
#  'GOOD-2H(7)': 'Unknown\n',
#  'GOT-IDEA': 'Up\n',
#  'GRAB': 'Away\n',
#  'GRAB-2': 'Away\n',
#  'GRAB-2H': 'Back and Forth\n',
#  'GRANDMOTHER': 'Unknown\n',
#  'GRANDMOTHER1': 'Unknown\n',
#  'GRANDMOTHER2': 'Up and Down\n',
#  'GRANDMOTHER2B': 'Down\n',
#  'GRANDMOTHER3': 'Up and Down\n',
#  'GRANDMOTHER3(3)': 'Down\n',
#  'GRASS': 'Sideways\n',
#  'GRASS(4)': 'Away\n',
#  'GRAZE': 'Away\n',
#  'GRAZE-1H': 'Local Movement\n',
#  'GRAZE-2H': 'Local Movement\n',
#  'GREEN': 'Towards\n',
#  'GREEN1': 'Towards\n',
#  'GREY': 'Vertical Circular\n',
#  'GREY1': 'Vertical Circular\n',
#  'GREY3-1H': 'Horizontal Circular\n',
#  'GROUND': 'Sideways\n',
#  'GROUP': 'Local Movement\n',
#  'GROW': 'Up\n',
#  'GROW-1H': 'Up\n',
#  'GRUDGE': 'Unknown\n',
#  'GRUDGE2': None,
#  'GRUMPY': 'Local Movement\n',
#  'GUFFAW': 'Away\n',
#  'GUN(HTHUMB)': 'Local Movement\n',
#  'HAIR': 'Local Movement\n',
#  'HAIR(GO)': 'Unknown\n',
#  'HAIR-BUN': 'Local Movement\n',
#  'HAIR-WASHING': 'Back and Forth\n',
#  'HAIRBRUSH': 'Up and Down\n',
#  'HAIRBRUSH(IRISHT)': 'Back and Forth\n',
#  'HALF': 'Sideways\n',
#  'HALF1': 'Sideways\n',
#  'HALF2': 'Sideways\n',
#  'HAND-1H': 'Local Movement\n',
#  'HAPPEN': 'Up\n',
#  'HAPPEN(2)': 'Up\n',
#  'HAPPY': 'Local Movement\n',
#  'HAPPY1': 'Local Movement\n',
#  'HARD': None,
#  'HARE': 'Local Movement\n',
#  'HAT': 'Unknown\n',
#  'HAT(5)-2H': 'Down\n',
#  'HAT-HEAD1': 'Unknown\n',
#  'HAT-HEAD1A': 'Down\n',
#  'HAVE': None,
#  'HAVE-2H': None,
#  'HAVE-NONE': None,
#  'HAVE-NONE-OF': None,
#  'HAVE-NONE-OF-2H': None,
#  'HAVE-NOT': 'Up\n',
#  'HAVE-NOT-2H': 'Unknown\n',
#  'HEAD': None,
#  'HEAR': 'Local Movement\n',
#  'HEAR2': None,
#  'HEAR2(1)': None,
#  'HEAR2(5)': 'Unknown\n',
#  'HEAR2(B)': None,
#  'HEARING1': None,
#  'HEART-THROB': None,
#  'HEART-THROB-1H': 'Local Movement\n',
#  'HEAVY': None,
#  'HELLO': None,
#  'HELLO1': None,
#  'HELP': None,
#  'HELP1': None,
#  'HI': None,
#  'HIDE1': None,
#  'HIDE1A': 'Unknown\n',
#  'HIGHWAY': 'Side to Side\n',
#  'HILL': None,
#  'HILLS': None,
#  'HOLD': None,
#  'HOLD-2H': 'Local Movement\n',
#  'HOLD-OFFER-BANANA': 'Away\n',
#  'HOLD-ON': 'Away\n',
#  'HOLD-ON(5)': None,
#  'HOLD-ON(B)': None,
#  'HOLD-ON-2H': 'Unknown\n',
#  'HOLE': 'Local Movement\n',
#  'HOLE1': 'Local Movement\n',
#  'HOLE2': None,
#  'HOLE2B': 'Local Movement\n',
#  'HOME': None,
#  'HOME-2H': None,
#  'HONEY': None,
#  'HOPE': None,
#  'HORNS': None,
#  'HORRIBLE': None,
#  'HORSE': None,
#  'HOT': 'Away\n',
#  'HOT(FALSE START)': None,
#  'HOT-2H': 'Away\n',
#  'HOUR': None,
#  'HOUR1': None,
#  'HOUSE': None,
#  'HOUSE(2)': 'Unknown\n',
#  'HOUSE(H)': 'Down\n',
#  'HOW': None,
#  'HOW-MANY': None,
#  'HOW1': None,
#  'HOW2': None,
#  'HUG': None,
#  'HUNGRY': 'Local Movement\n',
#  'HURRY': None,
#  'HURRY(H)': 'Down\n',
#  'HURT': None,
#  'IDEA': 'Away\n',
#  'IF': None,
#  'IGNORE': 'Down\n',
#  'IMAGINE3': 'Sideways\n',
#  'IMPOSSIBLE': None,
#  'IN': None,
#  'IN(2)': None,
#  'IN(FALSE-START)': None,
#  'IN(H)-1H': None,
#  'IN-1H': None,
#  'IN-CASE': None,
#  'INCECIPHERABLE': None,
#  'INCREDIBLE': None,
#  'INDECIPERABLE': 'Unknown\n',
#  'INDECIPHERABLE': None,
#  'INDECIPHERABLE(FALSE-START)': None,
#  'INDETERMINATE': None,
#  'INFORM': None,
#  'INFORM(B)': None,
#  'INSERT-COIN': 'Local Movement\n',
#  'INSIDE': None,
#  'INSIDE(FLATO)': None,
#  'INSIDE-1H': 'Unknown\n',
#  'INSTANT': None,
#  'INTEND2': None,
#  'INTEND2(F)': None,
#  'INTEREST': None,
#  'INTERESTED': None,
#  'INTERESTING': None,
#  'INTERMITTENT': None,
#  'INTERRUPT': None,
#  'INTERSECT': None,
#  'INTUITION': 'Unknown\n',
#  'INVENT': None,
#  'INVENT2': 'Up\n',
#  'IRRITATED': None,
#  'ISLAND1': None,
#  'IT(SE)': None,
#  'ITCH': 'Back and Forth\n',
#  'JACKET1(F)': None,
#  'JAR': None,
#  'JOIN2': 'Local Movement\n',
#  'JOKE': 'Away\n',
#  'JOKE-1H': None,
#  'JOKE-2': None,
#  'JOKE-2H': None,
#  'JOKE1-2H': 'Away\n',
#  'JOKE1-2H(FALSE-START)': None,
#  'JUMP': 'Up\n',
#  'JUMP-OFF': 'Up and Down\n',
#  'JUMP-UP': 'Up\n',
#  'JUMP-UP(P)': 'Up\n',
#  'JUMP-UP(variants)': None,
#  'JUMPER': 'Down\n',
#  'JUST(SE)': None,
#  'JUST-FOR-FUN': 'Down\n',
#  'KANGAROO': 'Up and Down\n',
#  'KEEN': 'Back and Forth\n',
#  'KEEN(BENT8)': None,
#  'KEEP': 'Sideways\n',
#  'KICK': 'Up and Down\n',
#  'KILL': None,
#  'KILL-X': 'Away\n',
#  'KISS': None,
#  'KNEEL': 'Down\n',
#  'KNIFE': None,
#  'KNIFE(H)': 'Down\n',
#  'KNOCK-1H': 'Local Movement\n',
#  'KNOW': None,
#  'KNOW(7)': None,
#  'KNOW-NOT': None,
#  'KNOW-NOT-2H': None,
#  'KNOW-YOU': 'Away\n',
#  'KNOW-YOU(CHEEK)': None,
#  'LAB7': None,
#  'LADY': 'Down\n',
#  'LADY1': None,
#  'LADY1(FALSE START)': None,
#  'LADY2': None,
#  'LARGE': 'Sideways\n',
#  'LARGE-HEAP': None,
#  'LAST': None,
#  'LAST-THREE-YEAR': 'Down\n',
#  'LATE': None,
#  'LATER': None,
#  'LATER(B)': 'Sideways\n',
#  'LAUGH': 'Side to Side\n',
#  'LAUGH(BC)': 'Side to Side\n',
#  'LAUGH-1H': None,
#  'LAUGH-AT': None,
#  'LEAF': None,
#  'LEAP-INTO-THE-AIR': 'Up\n',
#  'LEARN': None,
#  'LEARN-MY-LESSON': 'Away\n',
#  'LEARN2': 'Towards\n',
#  'LEARNT': None,
#  'LEAVING': 'Unknown\n',
#  'LEFT-SIDE': None,
#  'LEG': None,
#  'LENGTH': 'Away\n',
#  'LESS': 'Sideways\n',
#  'LESS(BENTB)': None,
#  "LET'S-SEE": None,
#  'LETS-SEE': None,
#  'LETTER': None,
#  'LIAR': 'Sideways\n',
#  'LICK': None,
#  'LICK-CHEEK': None,
#  'LICK-LOCATED': None,
#  'LICK-ON-FACE': None,
#  'LICK1A': 'Up\n',
#  'LID(SE)': 'Local Movement\n',
#  'LIE': None,
#  'LIE-DOWN': None,
#  'LIE-DOWN(BENT2)': 'Down\n',
#  'LIFE': None,
#  'LIGHT2': None,
#  'LIKE': None,
#  'LIKE1': None,
#  'LIKE2': 'Unknown\n',
#  'LIKE2-1H': None,
#  'LINE': 'Sideways\n',
#  'LINE(ASL)': 'Sideways\n',
#  'LINE-UP': 'Sideways\n',
#  'LINES': 'Sideways\n',
#  'LINES(1)': 'Sideways\n',
#  'LINES(FALSE-START)': None,
#  'LITTLE': None,
#  'LITTLE1B': None,
#  'LITTLE2': None,
#  'LIVE': None,
#  'LIVE-2H': None,
#  'LIVE2-2H': None,
#  'Loc': None,
#  'LOG': 'Vertical Circular\n',
#  'LOLLY': 'Local Movement\n',
#  'LONG': None,
#  'LONG-AGO': 'Unknown\n',
#  'LONG-HAIR': 'Down\n',
#  ...}

# %% [markdown]
# ## Primary Movement KeyBind.txt -> int

# %%
label_keys = {"Up\n":0, "Down\n":1, "Up and Down\n":2, "Sideways\n":3, 
              "Side to Side\n":4, "Away\n":5, "Towards\n":6, 
              "Back and Forth\n":7, "Horizontal Circular\n":8, 
              "Vertical Circular\n":9, "Local Movement\n":10, "Unknown\n": 11,}
label_keys
# Out:
# {'Up\n': 0,
#  'Down\n': 1,
#  'Up and Down\n': 2,
#  'Sideways\n': 3,
#  'Side to Side\n': 4,
#  'Away\n': 5,
#  'Towards\n': 6,
#  'Back and Forth\n': 7,
#  'Horizontal Circular\n': 8,
#  'Vertical Circular\n': 9,
#  'Local Movement\n': 10,
#  'Unknown\n': 11}

# %% [markdown]
# # Assign each data point to a classification
# ## Each of these will be classified to X and Y

# %%
coorDataLocation = "D:/Thesis/ELAR-Data/imputedArrayData/"
dirData = os.listdir(coorDataLocation)
videoWord = []
numBad = 0
numNone = 0
for i, data in enumerate(dirData):
    data = data.upper()
    if i % 2:
        continue
    try:
        movement = pathMovement[data.split("_")[0]]
        videoWord.append(label_keys[movement])
    except:
        if pathMovement[data.split("_")[0]] is None:
            numNone += 1
        numBad += 1
        print(data)
        videoWord.append(99) 
numBad, numNone, len(dirData)
# Out:
# BEDFRAME_BCHA2C7A_2180_4030.NPY
# BEFORE2_BFPB1C2A_34436_34766.NPY
# BOTTOM2_BSSA1C2B_70870_71770.NPY
# CALL_BFPB1C2A_126318_126648.NPY
# DAYBREAK_BCHA2C7A_39940_41160.NPY
# DON'T1-2H_BSSA1C2B_31650_32140.NPY
# FIND1_SATA2C7A_43760_44070.NPY
# FUNNY_AMMA1C2A_53334_53714.NPY
# HAVE-2H_AMGA1C2A_25120_25300.NPY
# HAVE-2H_MTFB3C9A_82080_82340.NPY
# HAVE-2H_PDSA2C7A_73770_73990.NPY
# HAVE-2H_SBS1A3C7A_2140_3080.NPY
# HAVE-2H_SGMB2C7A_102690_102810.NPY
# HAVE-2H_SPKA1C2A_22050_22300.NPY
# HAVE-2H_SPKA3C9A_49165_49465.NPY
# HAVE-2H_SSSB1C2A_30329_30660.NPY
# HAVE-2H_SSSB1C2A_9640_9930.NPY
# HAVE-NONE-OF-2H_MKB2A1C2A_62720_63040.NPY
# HAVE-NONE_PCNB2C7A_27370_27710.NPY
# YESTERDAY2(THREE)_BDCB1C2A_124850_125000.NPY
# YESTERDAY2(THREE)_BDCB1C2A_82350_82530.NPY
# YESTERDAY2(TWO)_BDCB1C2A_82060_82310.NPY
# YESTERDAY2_BDCB1C2A_124550_124740.NPY
# YESTERDAY2_BDCB1C2A_81620_82030.NPY
# YOUNG_MDPA3C9A_72510_72720.NPY
# YOUNG_MTFB3C9A_172740_173030.NPY
# YOUNG_PCNB3C9A_17870_18835.NPY
# YOUNG_PCNB3C9A_92830_93340.NPY
# YOUNG_SGMB2C7A_75530_75780.NPY
# YOUNG_SLRB2C7A_1500_1860.NPY
# ZOOM-OFF-7_PCNB2C7A_94840_95280.NPY
# ZOOM-OFF_AAM1A2C6II_33820_35040.NPY
# ZOOM-OFF_AKRA2C6II_25530_26310.NPY
# ZOOM-OFF_MDHB2C6III_14570_15130.NPY
# ZOOM-OFF_MFKA2C6II_31410_32120.NPY
# ZOOM-OFF_MKB2A2C6II_17030_17560.NPY
# ZOOM-OFF_PCHA2C7A_69030_69480.NPY
# ZOOM-OFF_PDSA2C7A_70410_71340.NPY
# ZOOM-OFF_PNAA2C7A_82530_83610.NPY
# ZOOM-OFF_SBS1A3C7A_56630_56940.NPY
# ZOOM-OFF_SGMB2C7A_144140_145130.NPY
# ZOOM-OFF_SSSB2C6II_25020_25910.NPY
# ZOOM-OFF_STBA1C2B_23170_23770.NPY
# ZOOM-OFF_STBA1C2B_36540_37860.NPY
# (6299, 6299, 28116)

# %% [markdown]
# ## Append X values with a Y data label

# %%
newX = []
newTitle = []
Y = []
print(len(X), len(videoWord))
for i, y in enumerate(videoWord):
    # 99 was assigned if an error occured when importing and 11 is for unknown datalabels
    if y != 99 and y != 11 and y != 10:
        newX.append(X[i])
        newTitle.append(title[i])
        Y.append(y)
X = newX
title = np.array(newTitle)
print(len(X), len(title))
# Out:
# 14058 14058
# 5432 5432

# %% [markdown]
# ## Remove X and Y that are low usability

# %%
print(len(X),len(Y))
newX = []
newY = []
for i in range(len(X)):
    if usability[title[i]] >= 3:
        newX.append(X[i])
        newY.append(Y[i])
X = np.array(newX)
Y = np.array(newY)
print(len(X),len(Y))
# Out:
# 5432 5432
# 2728 2728

# %% [markdown]
# ## check shape of data

# %%
newX = []
newY = []
for i in range(len(X)):
    try:
        if X[i].shape[1] == 33 or X[i].shape[2] == 3:
            newX.append(X[i])
            newY.append(Y[i])
    except:
        continue
X = np.array(newX)
Y = np.array(newY)

# %%
print(len(X), len(Y), len(originalX))
print(X.shape)
# Out:
# 2728 2728 14058
# (2728, 40, 33, 3)

# %% [markdown]
# # Reshape insto 1d shape

# %%
newX = []
for i in range(len(X)):
    newInfo = []
    for frame in X[i]:
        for joint in frame:
            for coor in joint:
                newInfo.append(coor)
    newX.append(newInfo)
X = np.array(newX)
print(X.shape)
# Out:
# (2728, 3960)

# %% [markdown]
# ## Create Training Splits

# %%
import random
import pandas as pd

# Random state
seed_value = 42  
random.seed(seed_value)

# Choose the test size
pick = False

yCount = {}
if pick:
    testSize = 0.33
else:
    for value in Y:
        if value in yCount:
            yCount[value] += 1
        else:
            yCount[value] = 1
    trainSize = min(yCount.values()) * len(yCount.keys())
    testSize =  1 -(trainSize / len(Y))

# set up random picking
picked = {i:0 for i in range(len(X))}
Yset = set(Y)
uniqueYs = len(Yset)
Ordered_X_train, X_test, Ordered_y_train, y_test = ([],[],[],[])

# Randomly add and even amoung of training data based off test size
numAdded = 1
while ((len(Ordered_X_train)/ len(X)) <  (1 - testSize)):
    for y in range(uniqueYs):
        index = np.random.randint(0, len(Y) - 1)
        while picked[index] == 1 or not Y[index] == y:
            index = random.randint(0, len(Y) - 1)
            if yCount[y] <= numAdded:
                print("too many added", yCount[y], numAdded)
                break
        picked[index] = 1
        Ordered_X_train.append(X[index])
        Ordered_y_train.append(y)
    numAdded += 1
print("Ordered Training set created")
    
# Add remaing values into test
for i, bool in picked.items():
    if not bool:
        X_test.append(X[i])
        y_test.append(Y[i])
print("Test set created")

# Randomly order training:
X_train, y_train = ([],[])
pickedReorder = {i:0 for i in range(len(Ordered_y_train))}
print(len(pickedReorder.values()))
index = np.random.randint(0, len(Ordered_y_train) - 1)
num = 0
while(np.prod(list(pickedReorder.values())) == 0):
    while pickedReorder[index] == 1:
        index = random.randint(0, len(Ordered_y_train) - 1)
    pickedReorder[index] = 1
    X_train.append(Ordered_X_train[index])
    y_train.append(Ordered_y_train[index])
    num += 1
print("Training set created")

# Print amounts of percentage of each Y value in training set
vCount = pd.DataFrame(y_train)
print(vCount.value_counts() / len(X))
# Out:
# too many added 84 84
# Ordered Training set created
# Test set created
# 840
# Training set created
# 0    0.030792
# 1    0.030792
# 2    0.030792
# 3    0.030792
# 4    0.030792
# 5    0.030792
# 6    0.030792
# 7    0.030792
# 8    0.030792
# 9    0.030792
# Name: count, dtype: float64

# %%
# Save Data
np.savetxt("experiment3/X_train.npy", X_train)
np.savetxt("experiment3/X_test.npy", X_test)
np.savetxt("experiment3/y_train.npy", y_train)
np.savetxt("experiment3/y_test.npy", y_test)

# %%
experimentData = ['experiment1', 'experiment2', 'experiment3', 'experiment4']
folder = experimentData[3 - 1]
# Save Data
X_train = np.loadtxt(folder + "/X_train.npy")
X_test = np.loadtxt(folder + "/X_test.npy")
y_train = np.loadtxt(folder + "/y_train.npy")
y_test = np.loadtxt(folder + "/y_test.npy")

# %% [markdown]
# ## Remove local movement

# %%
newX_train, newY_train, newX_test, newY_test = [], [], [], []
for i, label in enumerate(y_train):
    if label != 10:
        newX_train.append(X_train[i])
        newY_train.append(label)

for i, label in enumerate(y_test):
    if label != 10:
        newX_test.append(X_test[i])
        newY_test.append(label)

X_train, y_train, X_test, y_test = np.array(newX_train), np.array(newY_train), np.array(newX_test), np.array(newY_test)

# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
unique_classes, counts = np.unique(y_train, return_counts=True)

invs_label_key = {label_keys[key]: key for key in label_keys.keys()}
class_counts_df = pd.DataFrame({'Class': [invs_label_key[i][:-1] for i in unique_classes], 'Count': counts})

for label, count in zip(unique_classes, counts):
    print(f"Class {invs_label_key[label][:-1]}: {count} samples")
class_counts_df
# Out:
# Class Up: 84 samples
# Class Down: 84 samples
# Class Up and Down: 84 samples
# Class Sideways: 84 samples
# Class Side to Side: 84 samples
# Class Away: 84 samples
# Class Towards: 84 samples
# Class Back and Forth: 84 samples
# Class Horizontal Circular: 84 samples
# Class Vertical Circular: 84 samples
#                  Class  Count
# 0                   Up     84
# 1                 Down     84
# 2          Up and Down     84
# 3             Sideways     84
# 4         Side to Side     84
# 5                 Away     84
# 6              Towards     84
# 7       Back and Forth     84
# 8  Horizontal Circular     84
# 9    Vertical Circular     84

# %% [markdown]
# ## Linear Discriminant Analysis
# Quadratic discriminant analysis is a classification problem represented by a Bayes Probability distribution

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
# data to manipulate
ldas = []
for solver in ['svd', 'lsqr']:
    lda = LinearDiscriminantAnalysis(solver=solver)
    lda.fit(X_train, y_train)
    ldas.append(lda)
    print('\n', solver)
    # Error calculation
    print("training acuracy: ", lda.score(X_train, y_train))
    print("validation acuracy: ", lda.score(X_test, y_test))
    print("training error: ", 1 - lda.score(X_train, y_train))
    print("validation error: ", 1 - lda.score(X_test, y_test))
# Out:
#  svd
# training acuracy:  0.9511904761904761
# validation acuracy:  0.1620762711864407
# training error:  0.04880952380952386
# validation error:  0.8379237288135593
#
#  lsqr
# training acuracy:  0.1
# validation acuracy:  0.16896186440677965
# training error:  0.9
# validation error:  0.8310381355932204

# %%
from sklearn import metrics
import seaborn as sns
inverted_label_keys = dict(map(reversed, label_keys.items()))
label = [inverted_label_keys[i] for i in range(11)]

y_pred = ldas[0].predict(X_test)
cm = metrics.confusion_matrix(y_pred, y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label, yticklabels=label)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Linear Discriminant Analysis')
plt.show()

# %% [markdown]
# ## Quadratic Discriminant Analysis
# Quadratic discriminant analysis is a classification problem represented by a Bayes Probability distribution

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

qda = QuadraticDiscriminantAnalysis()
qda.fit(X_train, y_train)
# Error calculation
print("training acuracy: ", qda.score(X_train, y_train))
print("validation acuracy: ", qda.score(X_test, y_test))
print("training error: ", 1 - qda.score(X_train, y_train))
print("validation error: ", 1 - qda.score(X_test, y_test))
# Out:
# c:\Users\KAI\.conda\envs\ml\lib\site-packages\sklearn\discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# training acuracy:  1.0
# validation acuracy:  0.09639830508474577
# training error:  0.0
# validation error:  0.9036016949152542

# %%
from sklearn import metrics
import seaborn as sns
inverted_label_keys = dict(map(reversed, label_keys.items()))
label = [inverted_label_keys[i] for i in range(11)]

y_pred = qda.predict(X_test)
cm = metrics.confusion_matrix(y_pred, y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label, yticklabels=label)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Linear Discriminant Analysis')
plt.show()

# %% [markdown]
# ## Gaussian Naive Bayes
# models each as conforming to a Gaussian (normal) distribution

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(X_train, y_train)

print("training acuracy: ", gnb.score(X_train, y_train))
print("validation acuracy: ", gnb.score(X_test, y_test))
print("training error: ", 1 - gnb.score(X_train, y_train))
print("validation error: ", 1 - gnb.score(X_test, y_test))
# Out:
# training acuracy:  0.25833333333333336
# validation acuracy:  0.14777542372881355
# training error:  0.7416666666666667
# validation error:  0.8522245762711864

# %%
from sklearn import metrics
import seaborn as sns
inverted_label_keys = dict(map(reversed, label_keys.items()))
label = [inverted_label_keys[i] for i in range(11)]

y_pred = gnb.predict(X_test)
cm = metrics.confusion_matrix(y_pred, y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label, yticklabels=label)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Linear Discriminant Analysis')
plt.show()

# %% [markdown]
# ## KNeighbors Classifier
# Classifier implementing the k-nearest neighbors vote.

# %%
from sklearn.neighbors import KNeighborsClassifier
bottom = 0
top = 31
step = 5
predictClass = []
kNeighborsPredictions = []
for weight in ['uniform', 'distance']:
    for i in range(bottom, top,step):
        if i == 0:
            clf = KNeighborsClassifier(n_neighbors=1, weights=weight)
        else:
            clf = KNeighborsClassifier(n_neighbors=i, weights=weight)
        clf.fit(X_train, y_train)
        kNeighborsPredictions.append(clf)
    for neigh in kNeighborsPredictions:
        print(neigh)
        # Error calculation
        print("training acuracy: ", neigh.score(X_train, y_train))
        print("validation acuracy: ", neigh.score(X_test, y_test))
        print("training error: ", 1 - neigh.score(X_train, y_train))
        print("validation error: ", 1- neigh.score(X_test, y_test))
        print("\n")
# Out:
# KNeighborsClassifier(n_neighbors=1)
# training acuracy:  1.0
# validation acuracy:  0.14353813559322035
# training error:  0.0
# validation error:  0.8564618644067796
#
#
# KNeighborsClassifier()
# training acuracy:  0.40476190476190477
# validation acuracy:  0.15360169491525424
# training error:  0.5952380952380952
# validation error:  0.8463983050847458
#
#
# KNeighborsClassifier(n_neighbors=10)
# training acuracy:  0.31547619047619047
# validation acuracy:  0.1641949152542373
# training error:  0.6845238095238095
# validation error:  0.8358050847457628
#
#
# KNeighborsClassifier(n_neighbors=15)
# training acuracy:  0.2904761904761905
# validation acuracy:  0.16790254237288135
# training error:  0.7095238095238094
# validation error:  0.8320974576271186
#
#
# KNeighborsClassifier(n_neighbors=20)
# training acuracy:  0.2761904761904762
# validation acuracy:  0.16684322033898305
# training error:  0.7238095238095238
# validation error:  0.833156779661017
#
#
# KNeighborsClassifier(n_neighbors=25)
# training acuracy:  0.2630952380952381
# validation acuracy:  0.1583686440677966
# training error:  0.736904761904762
# validation error:  0.8416313559322034
#
#
# KNeighborsClassifier(n_neighbors=30)
# training acuracy:  0.24523809523809523
# validation acuracy:  0.15360169491525424
# training error:  0.7547619047619047
# validation error:  0.8463983050847458
#
#
# KNeighborsClassifier(n_neighbors=1)
# training acuracy:  1.0
# validation acuracy:  0.14353813559322035
# training error:  0.0
# validation error:  0.8564618644067796
#
#
# KNeighborsClassifier()
# training acuracy:  0.40476190476190477
# validation acuracy:  0.15360169491525424
# training error:  0.5952380952380952
# validation error:  0.8463983050847458
#
#
# KNeighborsClassifier(n_neighbors=10)
# training acuracy:  0.31547619047619047
# validation acuracy:  0.1641949152542373
# training error:  0.6845238095238095
# validation error:  0.8358050847457628
#
#
# KNeighborsClassifier(n_neighbors=15)
# training acuracy:  0.2904761904761905
# validation acuracy:  0.16790254237288135
# training error:  0.7095238095238094
# validation error:  0.8320974576271186
#
#
# KNeighborsClassifier(n_neighbors=20)
# training acuracy:  0.2761904761904762
# validation acuracy:  0.16684322033898305
# training error:  0.7238095238095238
# validation error:  0.833156779661017
#
#
# KNeighborsClassifier(n_neighbors=25)
# training acuracy:  0.2630952380952381
# validation acuracy:  0.1583686440677966
# training error:  0.736904761904762
# validation error:  0.8416313559322034
#
#
# KNeighborsClassifier(n_neighbors=30)
# training acuracy:  0.24523809523809523
# validation acuracy:  0.15360169491525424
# training error:  0.7547619047619047
# validation error:  0.8463983050847458
#
#
# KNeighborsClassifier(n_neighbors=1, weights='distance')
# training acuracy:  1.0
# validation acuracy:  0.14353813559322035
# training error:  0.0
# validation error:  0.8564618644067796
#
#
# KNeighborsClassifier(weights='distance')
# training acuracy:  1.0
# validation acuracy:  0.15466101694915255
# training error:  0.0
# validation error:  0.8453389830508474
#
#
# KNeighborsClassifier(n_neighbors=10, weights='distance')
# training acuracy:  1.0
# validation acuracy:  0.1594279661016949
# training error:  0.0
# validation error:  0.8405720338983051
#
#
# KNeighborsClassifier(n_neighbors=15, weights='distance')
# training acuracy:  1.0
# validation acuracy:  0.16101694915254236
# training error:  0.0
# validation error:  0.8389830508474576
#
#
# KNeighborsClassifier(n_neighbors=20, weights='distance')
# training acuracy:  1.0
# validation acuracy:  0.15995762711864406
# training error:  0.0
# validation error:  0.840042372881356
#
#
# KNeighborsClassifier(n_neighbors=25, weights='distance')
# training acuracy:  1.0
# validation acuracy:  0.1583686440677966
# training error:  0.0
# validation error:  0.8416313559322034
#
#
# KNeighborsClassifier(n_neighbors=30, weights='distance')
# training acuracy:  1.0
# validation acuracy:  0.1530720338983051
# training error:  0.0
# validation error:  0.8469279661016949

# %%
from sklearn import metrics
import seaborn as sns
inverted_label_keys = dict(map(reversed, label_keys.items()))
label = [inverted_label_keys[i] for i in range(11)]

y_pred = kNeighborsPredictions[3].predict(X_test)
cm = metrics.confusion_matrix(y_pred, y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label, yticklabels=label)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Linear Discriminant Analysis')
plt.show()

# %% [markdown]
# ## DecisionTreeClassifier
# A decision tree classifier.

# %%
from sklearn.tree import DecisionTreeClassifier
for criteria in ["gini", "entropy", "log_loss"]:
    for splitter in ["best", "random"]:
        deTree = DecisionTreeClassifier(criterion=criteria, splitter=splitter, max_depth=10, min_samples_split=10)
        print('criteria: ', criteria, 'splitter: ', splitter)
        deTree.fit(X_train, y_train)

        print("training acuracy: ", deTree.score(X_train, y_train))
        print("validation acuracy: ", deTree.score(X_test, y_test))
        print("training error: ", 1 - deTree.score(X_train, y_train))
        print("validation error: ", 1- deTree.score(X_test, y_test))
# Out:
# criteria:  gini splitter:  best
# training acuracy:  0.6035714285714285
# validation acuracy:  0.1965042372881356
# training error:  0.39642857142857146
# validation error:  0.8034957627118644
# criteria:  gini splitter:  random
# training acuracy:  0.5738095238095238
# validation acuracy:  0.1975635593220339
# training error:  0.42619047619047623
# validation error:  0.802436440677966
# criteria:  entropy splitter:  best
# training acuracy:  0.7178571428571429
# validation acuracy:  0.16260593220338984
# training error:  0.28214285714285714
# validation error:  0.8373940677966102
# criteria:  entropy splitter:  random
# training acuracy:  0.6666666666666666
# validation acuracy:  0.16260593220338984
# training error:  0.33333333333333337
# validation error:  0.8373940677966102
# criteria:  log_loss splitter:  best
# training acuracy:  0.7202380952380952
# validation acuracy:  0.16366525423728814
# training error:  0.27976190476190477
# validation error:  0.8363347457627118
# criteria:  log_loss splitter:  random
# training acuracy:  0.6678571428571428
# validation acuracy:  0.1408898305084746
# training error:  0.3321428571428572
# validation error:  0.8591101694915254

# %%
from sklearn import metrics
import seaborn as sns
inverted_label_keys = dict(map(reversed, label_keys.items()))
label = [inverted_label_keys[i] for i in range(11)]

y_pred = dtcs[3].predict(X_test)
cm = metrics.confusion_matrix(y_pred, y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label, yticklabels=label)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Linear Discriminant Analysis')
plt.show()

# %% [markdown]
# ## RandomForestClassifier
# A random forest classifier.

# %%
from sklearn.ensemble import RandomForestClassifier
rfcs = []
for criteria in ["gini", "entropy", "log_loss"]:
    rfc = RandomForestClassifier(criterion=criteria, min_samples_split=10, max_depth=8)
    rfc.fit(X_train, y_train)
    rfcs.append(rfc)
    print(rfc, criteria)
    print("training acuracy: ", rfc.score(X_train, y_train))
    print("validation acuracy: ", rfc.score(X_test, y_test))
    print("training error: ", 1 - rfc.score(X_train, y_train))
    print("validation error: ", 1- rfc.score(X_test, y_test))
# Out:
# RandomForestClassifier(max_depth=8, min_samples_split=10) gini
# training acuracy:  0.9202380952380952
# validation acuracy:  0.2590042372881356
# training error:  0.07976190476190481
# validation error:  0.7409957627118644
# RandomForestClassifier(criterion='entropy', max_depth=8, min_samples_split=10) entropy
# training acuracy:  0.9916666666666667
# validation acuracy:  0.243114406779661
# training error:  0.008333333333333304
# validation error:  0.756885593220339
# RandomForestClassifier(criterion='log_loss', max_depth=8, min_samples_split=10) log_loss
# training acuracy:  0.9880952380952381
# validation acuracy:  0.2330508474576271
# training error:  0.011904761904761862
# validation error:  0.7669491525423728

# %%
from sklearn import metrics
import seaborn as sns
inverted_label_keys = dict(map(reversed, label_keys.items()))
label = [inverted_label_keys[i] for i in range(11)]

with open('experiment3/RFC.pkl', 'rb') as file:
        rfc: RandomForestClassifier = pickle.load(file) 
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
cm = metrics.confusion_matrix(y_pred, y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label, yticklabels=label)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Linear Discriminant Analysis')
plt.show()

# %% [markdown]
# # Save Model

# %%
import pickle

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(solver='svd')
lda.fit(X_train, y_train)
with open('./experiment3/LDA.pkl', 'wb') as file:
    pickle.dump(lda, file)

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
qda = QuadraticDiscriminantAnalysis()
qda.fit(X_train, y_train)
with open('./experiment3/QDA.pkl', 'wb') as file:
    pickle.dump(qda, file)
# Out:
# c:\Users\KAI\.conda\envs\ml\lib\site-packages\sklearn\discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
with open('./experiment3/GNB.pkl', 'wb') as file:
    pickle.dump(gnb, file)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train, y_train)
with open('./experiment3/KNN.pkl', 'wb') as file:
    pickle.dump(knn, file)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(criterion='gini', splitter='random')
dtc.fit(X_train, y_train)
with open('./experiment3/DTC.pkl', 'wb') as file:
    pickle.dump(dtc, file)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(criterion='gini', min_samples_split=10, max_depth=8)
rfc.fit(X_train, y_train)
with open('./experiment3/RFC.pkl', 'wb') as file:
    pickle.dump(rfc, file)
