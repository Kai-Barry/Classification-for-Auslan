# %%
import json
import time
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import cv2
from pathlib import Path

# %% [markdown]
# # Getting File

# %%
# Opening JSON file
start = time.time()
with open('dict_spottings.json') as json_file:
    data = dict(json.load(json_file))

# %%
def removeType(string):
    return string[:-4]

# %%
videoLocation = 'D:/BOBSL/BOBSL200G/bobsl/videos'
videoTitles = os.listdir(videoLocation)

videoName = videoTitles[0]
targetVideo = videoLocation + '/' +videoName

videoTitlesEdited = list(map(removeType, videoTitles))

# %% [markdown]
# # Only Loading in files that I have Downloaded

# %%
wordsTrain = list(dict(data['train']).keys())

train = []
for word in wordsTrain:
    wordData = data['train'][word]
    for i in range(len(wordData['names'])):
        fileName = wordData['names'][i]
        if fileName in videoTitlesEdited:
            globalTime = wordData['global_times'][i]
            probs = wordData['probs'][i]
            train.append((word, fileName, globalTime, probs))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 9
#       7 fileName = wordData['names'][i]
#       8 if fileName in videoTitlesEdited:
# ----> 9     globalTime = wordData['global_times'][i]
#      10     probs = wordData['probs'][i]
#      11     train.append((word, fileName, globalTime, probs))
#
# KeyboardInterrupt:

# %%
wordsVal = list(dict(data['val']).keys())

val = []
for word in wordsVal:
    wordData = data['val'][word]
    for i in range(len(wordData['names'])):
        fileName = wordData['names'][i]
        if fileName in videoTitlesEdited:
            globalTime = wordData['global_times'][i]
            probs = wordData['probs'][i]
            val.append((word, fileName, globalTime, probs))

# %%
wordsTest = list(dict(data['test']).keys())

test = []
for word in wordsTest:
    wordData = data['test'][word]
    for i in range(len(wordData['names'])):
        fileName = wordData['names'][i]
        if fileName in videoTitlesEdited:
            globalTime = wordData['global_times'][i]
            probs = wordData['probs'][i]
            test.append((word, fileName, globalTime, probs))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       6 for i in range(len(wordData['names'])):
#       7     fileName = wordData['names'][i]
# ----> 8     if fileName in videoTitlesEdited:
#       9         globalTime = wordData['global_times'][i]
#      10         probs = wordData['probs'][i]
#
# NameError: name 'videoTitlesEdited' is not defined

# %%
print(len(train))
print(len(val))
print(len(test))

# %% [markdown]
# ## Create new file showing information about files i have

# %%
f1 = open("train.txt", "w")
for line in train:
    f1.write(str(line) + '\n')
f1.close()

f2 = open("val.txt", "w")
for line in val:
    f2.write(str(line) + '\n')
f2.close()

f3 = open("test.txt", "w")
for line in test:
    f3.write(str(line) + '\n')
f3.close()

# %% [markdown]
# # Creating smaller videos

# %%
sortedVideoList = []
for videoName in videoTitlesEdited:
    targeVideoInfo = []
    for wordInfo in val: # wordInfo = (word, fileName, globalTime, probs)
        if wordInfo[1] == videoName:
            targeVideoInfo.append(wordInfo)
    if len(targeVideoInfo) > 0:  
        sortedVideoList.append(targeVideoInfo)
sortedVideoList

# %%
video1 = sortedVideoList[0]
FPS = 25
parts = []
for info in video1:
    globalTime = info[2]
    frameStart = globalTime
    frameEnd = globalTime + 1.5
    parts.append((frameStart, frameEnd, info[0]))
parts = sorted(parts, key=lambda x: x[0])
f4 = open("check2.txt", "w")
for line in parts:
    f4.write(str(line) + '\n')
f4.close()

# %%
videoLocation = 'D:/BOBSL/BOBSL200G/bobsl/videos'
videoTitles = os.listdir(videoLocation)

saveLocation = 'D:/Thesis/Video-Segments'

videoName = video1[0][1]

# %%
def extract_segment(input_file, start_time, end_time, output_file):
    cap = cv2.VideoCapture(input_file)

    # Get video properties
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Calculate start and end frame
    start_frame = int(start_time * fps)
    end_frame = int(end_time * fps)

    # Set video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_file, fourcc, fps, (width, height))

    # Extract frames and write to output file
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        frame_num = int(cap.get(cv2.CAP_PROP_POS_FRAMES))
        if frame_num < start_frame:
            continue
        if frame_num > end_frame:
            break

        out.write(frame)

    # Release resources
    cap.release()
    out.release()

# %%
videoName = video1[0][1]
targetVideo = videoLocation + '/' + videoName + '.mp4'
saveLocation = 'D:/Thesis/Video-Segments'
j = 0
for start, end, word in parts:
    if j == 250:
        break
    
    output  = saveLocation + '/' + videoName + '-' + word + '-'+ str(int(start)) +'-' + str(int(end)) + '.mp4'
    path = Path(output)
    i = 1
    while(path.is_file()):
        continue
    print(output, start, end, word)
    extract_segment(targetVideo, start, end, output)
    j += 1

# %% [markdown]
# # ELAR Dataset

# %%
from pympi import Eaf

# %% [markdown]
# ### Function to extract signs from a video

# %%
def extract_segment_adpated(input_file, timesWord, output_loc, videoName):
    cap = cv2.VideoCapture(input_file)
    
    # Get video properties
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Extract frames and write to output file
    frames = {}
    print('video: start frame')
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        frame_num = int(cap.get(cv2.CAP_PROP_POS_FRAMES))
        frames[frame_num] = frame

    print('video: end frames')
    # Release resources
    cap.release()


    i = 0
    print('Start: creating segments')
    for start, end, word in timesWord:
        # print(i, start, end, word)
        output_file = output_loc + word +'_'+ videoName +'_' + str(int(start)) + '_' + str(int(end)) + '.mp4'

        # Calculate start and end frame
        start_frame = int(start * fps * 0.001)
        end_frame = int(end * fps * 0.001)

        # Set video writer
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_file, fourcc, fps, (width, height))
        for frame_num in range(start_frame, end_frame):
            try:
                frame = frames[frame_num]
            except KeyError as error:
                continue
            out.write(frame)
        out.release()
        i += 1
    print('Finished: creating segments')

# %% [markdown]
# ### Create segments by sign for one video file

# %%
videoName = 'AAM1A1c2a'
videoLocation = 'D:/Auslan/AUSLANRECO-I0569/data/ELAR Data/AAM1A1c2a - The Boy Who Cried Wolf'
targetVideo = videoLocation + '/' + videoName + '.mp4'
saveLocation = 'D:/Thesis/Video-Segments-AUSLAN'

fileEAF = 'D:/Auslan/AUSLANRECO-I0569/data/ELAR Data/AAM1A1c2a - The Boy Who Cried Wolf/AAM1A1c2a.eaf'
eaf = Eaf(fileEAF)

j = 0
timeWords = []
for key in list(eaf.tiers['RH-IDgloss'][0].keys()):
    if j == 250:
        break
    
    start = eaf.timeslots[eaf.tiers['RH-IDgloss'][0][key][0]]
    end = eaf.timeslots[eaf.tiers['RH-IDgloss'][0][key][1]]
    word = eaf.tiers['RH-IDgloss'][0][key][2]
    timeWords.append((start, end, word))
print('Words times finished')

extract_segment_adpated(targetVideo, timeWords, saveLocation + '/', videoName)

# %% [markdown]
# ### Convert All video Files

# %%
folderLocation = 'D:/Auslan/AUSLANRECO-I0569/data/ELAR Data/'
folderList = os.listdir(folderLocation)
saveLocationParent = 'D:/Thesis/Video-Segments-AUSLAN/' 

i = 0
for folderName in folderList:
    if folderName == '! Annotated Files':
        continue
    # Video File 
    videoLocation = folderLocation + folderName
    videoName = folderName.split()[0]
    targetVideo = videoLocation + '/' + videoName + '.mp4'
    # ELAR File
    fileEAF = videoLocation + '/' + videoName + '.eaf'
    try:
        eaf = Eaf(fileEAF)
    except FileNotFoundError as error:
        continue
    # Save Location
    path = os.path.join(saveLocationParent, videoName)
    try:
        os.mkdir(path)
    except OSError as error:
        print(error)

    saveLocation = saveLocationParent + videoName
    print(saveLocation)
    timeWords = []
    for key in list(eaf.tiers['RH-IDgloss'][0].keys()):
        start = eaf.timeslots[eaf.tiers['RH-IDgloss'][0][key][0]]
        end = eaf.timeslots[eaf.tiers['RH-IDgloss'][0][key][1]]
        word = eaf.tiers['RH-IDgloss'][0][key][2]
        timeWords.append((start, end, word))
    print('Words times finished')
    extract_segment_adpated(targetVideo, timeWords, saveLocation + '/', videoName)
    i+=1
# Out:
# D:/Thesis/Video-Segments-AUSLAN/AAM1A1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AAM1A2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AAM1A2c6iv
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AAM2A1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AAM2A2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AAM2A2c6iv
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AAPB1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AAPB2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AAPB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AASB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AASB2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/ACAA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/ACAA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/ACAA2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/ADCB2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/ADCB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/ADPA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/ADPA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AFLA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AFLA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AJPB1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AJPB2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AJPB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AKRA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AKRA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AMGA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AMGA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AMMA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AMMA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AMW1B1c2b
# Words times finished
# video: start frame
# C:\Users\KAI\AppData\Roaming\Python\Python39\site-packages\pympi\Elan.py:1471: UserWarning: Parsing unknown version of ELAN spec... This could result in errors...
#   warnings.warn('Parsing unknown version of ELAN spec... '
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AMW1B2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AMW1B2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AMW2A1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AMW2A2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AMW2A2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/ARGB2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/ARGB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AVBB2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/AVBB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BAOBB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BAOBB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BAPB1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BCHA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BCHA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BCHA2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BCPA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BCPA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BDCB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BDCB2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BDCB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BDHA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BDHA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BDLA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BDLA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BDLA2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BFPB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BFPB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BFSA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BGLB1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BGMQB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BGMQB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BKPA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BMKB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BPJB1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BRCA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BRCA2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BRHB1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BRVA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BRVA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BSSA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BSSA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BTMA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/BTMA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MBCB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MBCB2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MBCB3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MBHA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MBHA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MBHA3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MCDB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MCDB2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MCDB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MCHA2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MDBB1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MDBB2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MDHB2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MDHB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MDPA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MDPA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MDPA3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MFKA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MFKA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MGCA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MGCA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MKB1B1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MKB1B2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MKB1B2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MKB1B3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MKB2A1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MKB2A2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MKB2A3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MMAA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MMAA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MOFB2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MOFB3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MSLB1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MSLB2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MSLB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MSQA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MTDBA2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MTDBA2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MTFB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MTFB2c6iii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MTFB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MTFB3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MVSB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/MVSB3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PCHA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PCHA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PCHA2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PCHA3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PCNB1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PCNB2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PCNB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PCNB3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PDCB2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PDCB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PDCB3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PDHA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PDRA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PDSA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PDSA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PDSA2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PDSA3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PGMB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PHHA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PHHA2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PJEB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PJLGA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PJPB1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PNAA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PNAA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PNAA2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PRFA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PTKA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PTKA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/PTKA2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SASA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SASA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SASA2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SASA3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SATA2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SAWB1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SBS1A1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SBS1A2c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SBS1A3c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SGMB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SGMB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SKPB2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SLRB1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SLRB2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SLWA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SLWA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SLWA3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SMCB1c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SMCB2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SMGB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SNCB2c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SNCB2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SPKA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SPKA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SPKA3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SSNA1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SSNA2c7a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SSNA3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SSSB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/SSSB2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/STBA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/STBA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/STBA3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/STCA1c2b
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/STCA2c6ii
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/STCA3c9a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments
# D:/Thesis/Video-Segments-AUSLAN/STMB1c2a
# Words times finished
# video: start frame
# video: end frames
# Start: creating segments
# Finished: creating segments

# %% [markdown]
# ### Test Stuff

# %%
output  = saveLocation + '/' + 'test' + '-' + word + '-'+ str(int(start)) +'-' + str(int(end)) + '.mp4'
extract_segment(targetVideo, 100, 110, output)

# %% [markdown]
# ### How many include both Subtitles

# %%
folderLocation = 'D:/Auslan/AUSLANRECO-I0569/data/ELAR Data/'
folderList = os.listdir(folderLocation)
i=0
j=0
for folderName in folderList:
        j+=1
        if folderName == '! Annotated Files':
                continue
        videoName = folderName.split()[0]
        videoLocation = folderLocation + folderName
        # print(folderLocation + folderName)
        # ELAR File
        fileEAF = videoLocation + '/' + videoName + '.eaf'
        # print(fileEAF)
        try:
                eaf = Eaf(fileEAF)
        except FileNotFoundError as error:
                continue
        if len(eaf.tiers['FreeTransl'][0]):
                i += 1
print(i)
print(j)
# Out:
# C:\Users\KAI\AppData\Roaming\Python\Python39\site-packages\pympi\Elan.py:1471: UserWarning: Parsing unknown version of ELAN spec... This could result in errors...
#   warnings.warn('Parsing unknown version of ELAN spec... '
# 103
# 211

# %% [markdown]
# ## Create Pose Data

# %%
import os
import mediapipe as mp
import cv2
import numpy as np
import pandas as pd

# %%
# initialize Pose estimator
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose


videoLocation = 'D:/Thesis/Video-Auslan-sorted'

for word in os.listdir(videoLocation):
    
    wordLocation = videoLocation + '/' + word
    print(wordLocation)
    # Loop through every video
    for videoName in os.listdir(wordLocation): 
        coordinates = []
        
        print('opening: ' + wordLocation + '/' + videoName)
        vid = cv2.VideoCapture(wordLocation + '/' + videoName)

        if (vid.isOpened()== False): 
            print("Error opening video stream or file")
        frames = 0
        with mp_pose.Pose(
            min_detection_confidence=0.5,
            min_tracking_confidence=0.5) as pose:
            while vid.isOpened():
                success, image = vid.read()
                frames += 1
                if not success:
                    print("Ignoring empty camera frame.")
                    break
                image_height, image_width, _ = image.shape

                # To improve performance, optionally mark the image as not writeable to
                # pass by reference.
                image.flags.writeable = False
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                results = pose.process(image)

                if not results.pose_landmarks:
                    continue
                else:
                    coordinates.append(results.pose_landmarks.landmark)

                # Draw the hand annotations on the image.
                image.flags.writeable = True
                image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

                # process image
                results = pose.process(image)
                results

                # draw landmarks
                mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

                # Display image
                # cv2.imshow('MediaPipe Pose', image)
                if cv2.waitKey(5) & 0xFF == 27:
                    break
        vid.release()
        cv2.destroyAllWindows()
        
        coor = []
        for frame in coordinates:
            coorFrame = []
            for landmarks in frame:
                coorFrame.append((landmarks.x * -1, landmarks.y * -1, landmarks.z * -1))
            coor.append(coorFrame)
        coor = np.array(coor)
        if len(coor) > 0:
            print("saving: ", videoName[:-4])
            np.savetxt("D:/Thesis/ELAR-Data/arrayData/"+ videoName[:-4] +".npy", coor.reshape(coor.shape[0], -1))
            np.savetxt("D:/Thesis/ELAR-Data/arrayData/"+ videoName[:-4] +"_shape.npy", np.array(coor.shape))
#             coorLoad = np.loadtxt("D:/Thesis/test.npy")
#             coorLoad = coorLoad.reshape(coorLoad.shape[0], coorLoad.shape[1] // coor.shape[2], coor.shape[2])
# Out:
# D:/Thesis/Video-Auslan-sorted/ABOUT1
# opening: D:/Thesis/Video-Auslan-sorted/ABOU
# Ignoring empty camera frame.
# saving:  ALL-2H_PHHA1c2a_15480_16730
# D:/Thesis/Video-Auslan-sorted/ALL-DAY
# opening: D:/Thesis/Video-Auslan-sorted/ALL-DAY/ALL-DAY_AKRA1c2a_22340_23184.mp4
# Ignoring empty camera frame.
# saving:  ALL-DAY_AKRA1c2a_22340_23184
# opening: D:/Thesis/Video-Auslan-sorted/ALL-DAY/ALL-DAY_MMAA1c2a_64415_65005.mp4
# Ignoring empty camera frame.
# saving:  ALL-DAY_MMAA1c2a_64415_65005
# opening: D:/Thesis/Video-Auslan-sorted/ALL-DAY/ALL-DAY_SMGB1c2a_32504_34014.mp4
# Ignoring empty camera frame.
# saving:  ALL-DAY_SMGB1c2a_32504_34014
# opening: D:/Thesis/Video-Auslan-sorted/ALL-DAY/ALL-DAY_SSNA1c2a_12340_13250.mp4
# Ignoring empty camera frame.
# D:/Thesis/Video-Auslan-sorted/ALL-DAY-2H
# opening: D:/Thesis/Video-Auslan-sorted/ALL-DAY-2H/ALL-DAY-2H_PGMB1c2a_41591_41891.mp4
# Ignoring empty camera frame.
# saving:  ALL-DAY-2H_PGMB1c2a_41591_41891
# D:/Thesis/Video-Auslan-sorted/ALL-DAY-LONG
# opening: D:/Thesis/Video-Auslan-sorted/ALL-DAY-LONG/ALL-DAY-LONG_MTFB1c2a_53525_55215.mp4
# Ignoring empty camera frame.
# saving:  ALL-DAY-LONG_MTFB1c2a_53525_55215
# D:/Thesis/Video-Auslan-sorted/ALLOW
# opening: D:/Thesis/Video-Auslan-sorted/ALLOW/ALLOW_SLWA1c2a_18882_19142.mp4
# Ignoring empty camera frame.
# saving:  ALLOW_SLWA1c2a_18882_19142
# D:/Thesis/Video-Auslan-sorted/ALMOST
# opening: D:/Thesis/Video-Auslan-sorted/ALMOST/ALMOST_AFLA1c2b_47940_48120.mp4
# Ignoring empty camera frame.
# saving:  ALMOST_AFLA1c2b_47940_48120
# opening: D:/Thesis/Video-Auslan-sorted/ALMOST/ALMOST_AFLA1c2b_66590_66740.mp4
# Ignoring empty camera frame.
# saving:  ALMOST_AFLA1c2b_66590_66740
# opening: D:/Thesis/Video-Auslan-sorted/ALMOST/ALMOST_BPJB1c2b_87680_87910.mp4
# Error opening video stream or file
# opening: D:/Thesis/Video-Auslan-sorted/ALMOST/ALMOST_BRHB1c2b_45660_45990.mp4
# Ignoring empty camera frame.
# saving:  ALMOST_BRHB1c2b_45660_45990
# opening: D:/Thesis/Video-Auslan-sorted/ALMOST/ALMOST_BSSA1c2b_167710_167890.mp4
# Ignoring empty camera frame.
# opening: D:/Thesis/Video-Auslan-sorted/ALMOST/ALMOST_BSSA1c2b_168440_168730.mp4
# Ignoring empty camera frame.
# opening: D:/Thesis/Video-Auslan-sorted/ALMOST/ALMOST_BTMA1c2b_57300_57620.mp4
# Ignoring empty camera frame.
# saving:  ALMOST_BTMA1c2b_57300_57620
# opening: D:/Thesis/Video-Auslan-sorted/ALMOST/ALMOST_MSLB1c2b_94569_94779.mp4
# Ignoring empty camera frame.
# saving:  ALMOST_MSLB1c2b_94569_94779
# opening: D:/Thesis/Video-Auslan-sorted/ALMOST/ALMOST_PRFA1c2b_35660_36210.mp4
# Ignoring empty camera frame.
# saving:  ALMOST_PRFA1c2b_35660_36210
# opening: D:/Thesis/Video-Auslan-sorted/ALMOST/ALMOST_PTKA1c2b_78940_79220.mp4
# Ignoring empty camera frame.
# saving:  ALMOST_PTKA1c2b_78940_79220
# opening: D:/Thesis/Video-Auslan-sorted/ALMOST/ALMOST_SASA1c2b_68423_68783.mp4
# Ignoring empty camera frame.
# saving:  ALMOST_SASA1c2b_68423_68783
# D:/Thesis/Video-Auslan-sorted/ALMOST(FLATGO)
# opening: D:/Thesis/Video-Auslan-sorted/ALMOST(FLATGO)/ALMOST(FLATGO)_BRVA1c2b_51000_51450.mp4
# Ignoring empty camera frame.
# opening: D:/Thesis/Video-Auslan-sorted/ALMO
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_AAPB2c7a_121107_122287.mp4
# Ignoring empty camera frame.
# saving:  BEE_AAPB2c7a_121107_122287
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_AAPB2c7a_123337_123967.mp4
# Ignoring empty camera frame.
# saving:  BEE_AAPB2c7a_123337_123967
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_AAPB2c7a_144670_145560.mp4
# Ignoring empty camera frame.
# saving:  BEE_AAPB2c7a_144670_145560
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_AAPB2c7a_93918_94748.mp4
# Ignoring empty camera frame.
# saving:  BEE_AAPB2c7a_93918_94748
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_ADCB2c7a_64846_65736.mp4
# Ignoring empty camera frame.
# saving:  BEE_ADCB2c7a_64846_65736
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_ADCB2c7a_71790_72200.mp4
# Ignoring empty camera frame.
# saving:  BEE_ADCB2c7a_71790_72200
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_ADCB2c7a_96260_96730.mp4
# Ignoring empty camera frame.
# saving:  BEE_ADCB2c7a_96260_96730
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_AMW1B2c7a_37278_38128.mp4
# Ignoring empty camera frame.
# saving:  BEE_AMW1B2c7a_37278_38128
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_AMW2A2c7a_127548_129264.mp4
# Ignoring empty camera frame.
# saving:  BEE_AMW2A2c7a_127548_129264
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_AMW2A2c7a_129931_131281.mp4
# Ignoring empty camera frame.
# saving:  BEE_AMW2A2c7a_129931_131281
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_AMW2A2c7a_88883_92033.mp4
# Ignoring empty camera frame.
# saving:  BEE_AMW2A2c7a_88883_92033
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_BAOBB2c7a_41440_41840.mp4
# Ignoring empty camera frame.
# saving:  BEE_BAOBB2c7a_41440_41840
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_BAOBB2c7a_42530_43140.mp4
# Ignoring empty camera frame.
# saving:  BEE_BAOBB2c7a_42530_43140
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_BDLA2c7a_55820_56230.mp4
# Ignoring empty camera frame.
# saving:  BEE_BDLA2c7a_55820_56230
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_BDLA2c7a_82360_82720.mp4
# Error opening video stream or file
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_BGMQB2c7a_48510_48870.mp4
# Ignoring empty camera frame.
# saving:  BEE_BGMQB2c7a_48510_48870
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_BGMQB2c7a_49360_49710.mp4
# Ignoring empty camera frame.
# saving:  BEE_BGMQB2c7a_49360_49710
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_BGMQB2c7a_51790_52290.mp4
# Ignoring empty camera frame.
# saving:  BEE_BGMQB2c7a_51790_52290
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_BGMQB2c7a_69120_69350.mp4
# Ignoring empty camera frame.
# saving:  BEE_BGMQB2c7a_69120_69350
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_BGMQB2c7a_86060_86460.mp4
# Ignoring empty camera frame.
# saving:  BEE_BGMQB2c7a_86060_86460
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_MKB1B2c7a_138094_138904.mp4
# Error opening video stream or file
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_MKB1B2c7a_147249_149319.mp4
# Error opening video stream or file
# opening: D:/Thesis/Video-Auslan-sorted/BEE/BEE_MKB1B2c7a_189250_190620.mp4

# %%
labelLocation = 'D:/Thesis/ELAR-Data/label.csv'
labelDf = pd.read_csv(label)
labelDict = dict(np.array(labelDf))

# %%
Y= []
coorDataLocation = "D:/Thesis/ELAR-Data/arrayData/"
dirData = os.listdir(coorDataLocation)
for i, data in enumerate(dirData):
    if 'shape' in data:
        continue
    fileLocation = coorDataLocation + data
    shapeLocation = coorDataLocation + dirData.get(i+1)
    coorLoad = np.loadtxt(fileLocation)
    coorShape= np.loadtxt(shapeLocation)
    coorLoad = coorLoad.reshape(coorLoad.shape[0], coorLoad.shape[1] // coorShape[2], coorShape[2])
    Y.append(data.split('_')[0])
