# %% [markdown]
# ## number of curropted videos

# %%
corrupted = ['AJBB1c2b',
'AJPB1c2b',
'AMMA1c2a',
'AWGB1c2a',
'BAOBB1c2a',
'BCPA1c2a',
'BDLA1c2a',
'BFPB1c2a',
'BFSA1c2a',
'BGLB1c2b',
'BRCA1c2a',
'BRVA1c2b',
'BSSA1c2b',
'BCHA2c7a',
'SSNA1c2a']
len(corrupted)
# Out:
# 15

# %%
from pympi import Eaf
import numpy as np
import os

# %%
videoName = 'AAM1A1c2a'
videoLocation = 'D:/Auslan/AUSLANRECO-I0569/data/ELAR Data/AAM1A1c2a - The Boy Who Cried Wolf'
targetVideo = videoLocation + '/' + videoName + '.mp4'
saveLocation = 'D:/Thesis/Video-Segments-AUSLAN'

fileEAF = 'D:/Auslan/AUSLANRECO-I0569/data/ELAR Data/AAM1A1c2a - The Boy Who Cried Wolf/AAM1A1c2a.eaf'
eaf = Eaf(fileEAF)
print(len(eaf.tiers['RH-IDgloss'][0]))
print(len(eaf.tiers['RH-IDgloss'][0]))
# Out:
# 185
# 185

# %% [markdown]
# ## number of each story

# %%
folderLocation = 'D:/Auslan/AUSLANRECO-I0569/data/ELAR Data/'
folderList = os.listdir(folderLocation)
saveLocationParent = 'D:/Thesis/Video-Segments-AUSLAN/' 

i = 0
numStory = {}
for folderName in folderList:
    if folderName == '! Annotated Files' or folderName == "Readme.md":
        continue
    storyType = folderName.split(' - ')[1]
    if storyType in numStory:
        numStory[storyType] += 1
    else:
        numStory[storyType] = 1
print(numStory)
# Out:
# {'The Boy Who Cried Wolf': 46, 'Canary Row cartoon': 67, 'The Hare and the Tortoise': 33, 'Frog Where Are You': 41, 'Sign order elicitation task': 22}

# %% [markdown]
# ## Number of times signs

# %%
folderLocation = 'D:/Auslan/AUSLANRECO-I0569/data/ELAR Data/'
folderList = os.listdir(folderLocation)
allWords = set()
numAllWords = {}
i = 0
words = {}
story = {}
for folderName in folderList:
    if folderName == '! Annotated Files' or folderName == "Readme.md":
        continue
    storyType = folderName.split(' - ')[1]

    if storyType not in words:
        story[storyType] = set()

    # ELAR File
    videoLocation = folderLocation + folderName
    videoName = folderName.split()[0]
    files = os.listdir(videoLocation)
    for file in files:
        if '.eaf' in file:
            eaf = Eaf(videoLocation + '/' + file)
    
    timeWords = []
    for key in list(eaf.tiers['RH-IDgloss'][0].keys()):
        start = eaf.timeslots[eaf.tiers['RH-IDgloss'][0][key][0]]
        end = eaf.timeslots[eaf.tiers['RH-IDgloss'][0][key][1]]
        word = eaf.tiers['RH-IDgloss'][0][key][2]
        if word in numAllWords:
            numAllWords[word] += 1
        else:
            numAllWords[word] = 1
        allWords.add(word)
        story[storyType].add(word)
        timeWords.append((start, end, word))
# Out:
# c:\Users\KAI\.conda\envs\ml\lib\site-packages\pympi\Elan.py:1471: UserWarning: Parsing unknown version of ELAN spec... This could result in errors...
#   warnings.warn('Parsing unknown version of ELAN spec... '

# %%
print(allWords)
print(numAllWords)
len(allWords)
# Out:
# {'', 'LINES(1)', 'DSM(BENT2):ANIMAL-REACHES-THERE', 'G(NMS):WHATEVER', 'G(5-UP):HOW', 'WENT', 'BRICKLAYER(B)', 'DSM(BENT2):ANIMAL-LIES-ON-THE-BED', "DS(1):HARE'S-PATH", 'PT:DETPL-2H(RELAXED)', 'FS:METRE(METK)', 'SECRET', 'DSS(5):WOLF', 'DS(4):ANIMAL-IS-COMING', 'G(CA):HUMAN-HOLDS-ONTO-THE-TREE-BRANCH', 'CHASE2', 'TINY', 'DSM(5):SHEEP-SCATTERED', 'MAN(FALSE-START)', 'PT:POSS3SG(B)', 'G:OH-I-AM-WRONG', 'FS:AND', 'ANGRY1', 'IDEA', 'DSM(H):HUMAN-MOVES-OVER-LOG', 'CLIFF-2H', 'DSS(BC):CYLINDRICAL-LOG', 'PERFECT', 'DS(BENT5):THE-MONKEY-DOFFS-HIS-HAT', 'DS(BENT5):THE-MONKEY-RUNS', 'DS(2BENT):ANIMAL-IS-THROWN-OUT', 'FS:GAMES', 'DSM(2):ANIMAL-FALL-FROM-CLIFF', 'DSL(5):SPERICAL-HIVE', 'DS(5):SMASH!', 'PLAY', 'DSM(BENT2):THE-MONKEY-HOPS', 'DS(UNKNOWN):ANIMAL-RUNS-AND-THEN-STOPS', 'EXPLORE', 'G(CA):BOY-HOLDS-THE-BRANCHES', "DS(BENT5):THE-MONKEY'S-HAT-IS-DOFFED", 'DSL(BENT2):HUMAN-ON-DEER', 'FS:EUROPE', 'DSS(BC):VERTICAL-CYLINDER-DOWNPIPE', 'DS(5):THE-BEES-FLY', 'G(5-WIGGLE):ERR', 'FBUOY', 'FEW(FALSE-START)', 'FS:RAINPIPE', 'MARRIED', 'VERY-HOT', 'DSM(1):ANIMAL-COME', 'FLAT-SURFACE', 'G:OH', 'TEACH', 'DSM(BENT2):ANIMAL-RUNS', 'BETTER', "DS(IRISHT):ANIMAL-WEARS-THE-MONKEY'S-HAT", 'FS:MANTEL(MANTE)', 'PT:FBUOY-BABY', 'DSM(5):ANIMAL-MOVE', 'CHAIR2(BENTB)', 'FBUOY:DSL(1-VERT):HUMAN', 'DSL(2):ANIMAL-LIES', 'DSM(2):HUMAN-GETS-ON-OBJECT', 'FS:TV', 'DS(S):ANIMAL-IS-DIZZY-AND-FALLS-TO-THE-GROUND', 'AMERINDIAN(FALSE START)', 'INTEND2', 'DS(S):THE-BANANA', 'OPPOSE', 'FRUSTRATED2', 'DS(B):SNAPSHOT-OF-RABBIT-AS-TORTOISE-CROSSES-FINISH-LINE', 'DSM(1-VERT):ANIMAL-FOLLOWS-HUMAN', 'DSM(1-HORI):ANIMAL-MOVES-OUT-OF-HOLE', 'ONE-2H', 'DS(1):REFERENCE-POINT', 'DSM(FLATBC):ANIMAL-CROAKS', 'ISLAND1', 'FS:SHOW', 'DS(1):POINT-OF-ARRIVAL', 'FS:KO', "DSL(5):ANIMAL'S-HEAD-IN-THE-JAR", 'STAND-1H', 'BREATHE', 'PT:FBUOY-BANNANA', 'DSH(5):FLOCK-OF-SHEEP', 'PLEASED', 'DS(1):ANIMAL-WITH-THE-BALL-SLIDES', 'ALMOST-2H', 'DS(INDEFINITE):FIGHT', 'DS(F):DESCRIPTION-OF-THE-ANTLER', 'DSM(5):MANY-HUMANS-LOOK', 'PUSH(5)', 'FS:TWEETY(TWEENY)', 'DSS(GCFLAT):LONG-THIN-OBJECT-EXTEND', 'DSS(5-HORI):MOVE-GROUP', 'FBUOY:THE-BASIN', 'DSM(5):SHEEP-MINGLING', 'GIGGLE', 'DSS(O):THIN-CYLINDRICAL-OBJECT-EXTEND', 'SHOW', 'TERROR', "DS(3):ANIMAL'S-EAR?", 'LADY2', 'DEER(FALSE-START)', 'DSM(Bb):ANIMAL-WITH-HEAD-IN-JAR-LOOKS-AROUND', 'DSS(BO):SOFT-NOISES-SOUND', 'DSM(BENT2):ANIMAL-FALLS-TO-THE-GROUND', 'DSL(1-VERT):TWO-ANIMALS-BE-AT-TOGETHER', 'DSM(BENT2):CAT-CLIMBS-UP', 'READY', 'DSM(5):WATER-RISES', 'SCARED', 'DEPRESS', 'GRASS', 'FS:SPOUTING', 'G:HMMM', 'CA:GIRL', 'PARENTS', 'FS:BEAVER', 'DS(B):ANIMAL-IS-ANXIOUSLY-LOOKING-AT-THE-HARE', 'DS:DOING(DING)', 'DSS(HBENT):ANIMALS-IN-LINE', 'DS(F):GLASS', 'REST', 'DSM(S):TURTLE-WALKING', 'DSS(5):SURFACE-BODY', 'PT:LOC/PRO3SG-2H(RELAXED)', 'FS:SKIN', 'GRASS(4)', 'DS(FLATO):THE-WOMAN-TAKES-SOMETHING-LIKE-A-COIN-OUT-OF-SOMETHING-LIKE-A-PURSE-AND-GIVE-IT-TO-THE-CAT', 'FS:DO', 'DSS(BENTB):EAT-A-PIECE-OF-PIZZA', 'BELIEVE-NOT2', 'DSS(B):LEG', 'NAME', 'DSM(2-DOWN):HUMAN-AND-ANIMAL-WALK', 'GRUDGE2', 'G(5-DOWN):WELL-1H', 'DS(BENT5):THE-GROUND', 'DSM(5):ACTIVITY', 'DSS(BENT5):CURVED-JAR', 'ME+GOOD', 'DSS(BC):VERTICAL-CYLINDER-DOWNPIPE-OR-POLE', 'REMEMBER1', 'WHISTLE1', 'REALLY-FAST', 'RIDICULOUS?', 'DS(1):HEIGHT', 'FROG2', "DS(1):THE-BALL-ENTERS-THE-CAT'S-MOUTH", 'ALLOW', 'FS:PLACE', 'G:WAITING-POSTURE', 'G(CA):BOY-LIFTS-AT-A-HEAD-LEVEL', 'DOG3', 'DSL(BENT2):ANIMALS-ON-LOG', 'FS:ATE(A)(FALSE-START)', 'PT:PRO3PL   ', 'FLOWER(F)', 'BECAUSE2', 'DSL(1-VERT):ANIMAL', 'DSM(BC):ANIMAL-HEAD-MOVE-INTO-JAR', 'G(ILY):UMM', 'QUOTE', 'OUT', 'DSM(BENTB):WINDOW-POPS-OUT', 'LADY1(FALSE START)', 'DSH(BC):HAT', 'DSM(1):HUMAN-MOVES', 'DSS(FLATBC):BRICK', 'DSM(2):HUMAN-LIES-ON-DEER-HEAD', 'STREET(3)', 'DSM(HBENT):HUMAN-SWIMS-TO-BANK', 'FS:TRUCK', 'FS:BRICKLAYER', 'DS(4):MANY-HUMANS-WATCHING-ON', 'HELLO1', 'DSM(1-HORI):HUMAN-RUNS', 'FS:BEEHIVE(HIVEBEE)', 'NEXT(FALSE-START)', 'IT(SE)', 'DS(1):ANIMAL-ENTERS-THE-BOWL', 'G(5-UP):WELL-NEGATION', 'DSS(S):CYLINDER-PIPE', 'DS(GCFLAT):ANIMAL-TAKES- ...
# {'PAST': 19, 'GO-IN': 3, 'PT:DET': 320, 'COUNTRY': 10, 'FAR': 33, 'FS:FARM': 1, 'HAVE': 236, 'ONE': 158, 'BOY': 578, 'WHO': 16, 'ALWAYS': 23, 'TAKE-2H': 7, 'SHEEP2': 27, 'AREA': 61, 'FROM': 18, 'HOUSE': 55, 'PT:POSS3PL': 12, 'TAKE': 44, 'BRING': 8, 'HILL': 17, 'PT-TRACE': 1, 'FOR?': 2, 'GRAZE': 57, 'SAME': 129, 'LOOK': 554, 'THINK-NOTHING': 1, 'TIME2': 8, 'FAST1': 12, 'GOOD-2H': 62, 'ENJOY': 4, 'DSM(5):ACTIVITY': 1, 'HOME-2H': 3, 'FS:DAY': 4, 'PT:PRO3SG': 402, 'GET(SE)': 1, 'BORED': 16, 'UNSURE': 1, 'WANT': 66, 'PLAY': 36, 'FS:UP': 1, 'FS:SO': 32, 'PT:': 17, 'CRY-1H': 1, 'GAME': 13, 'YELL2': 49, 'CRY': 34, 'WOLF': 278, 'PEOPLE': 155, 'FS:VILLAGE': 75, 'HEAR': 28, 'DSM(G):MANY-HUMANS-RUN': 1, 'ONLY': 22, 'SEE': 170, 'DSM(2):ROLL-ABOUT': 2, 'LAUGH': 89, 'HOLD-ON': 19, 'PT:PRO2SG': 102, 'STUPID2': 5, 'JOKE': 33, 'FS:S': 8, 'DSM1-VERT):ENTITY-CROWD-MOVE': 3, 'IRRITATED': 4, 'G(5-UP):WELL': 520, 'LATER': 27, 'CAN': 46, 'REPEAT': 72, 'TWO': 48, 'FEW': 5, 'OVER': 32, 'SPRINT': 86, 'DSM(5):MANY-FILE': 1, 'ALL': 75, 'WHAT-2H': 38, 'INDECIPHERABLE': 91, 'MAKE': 27, 'JOKE-1H': 3, 'FS:THEN': 5, 'DAY': 96, 'REPEAT-2H': 5, 'FUNNY-STRANGE': 13, 'FS:BUT': 7, 'NOT': 92, 'COME': 77, 'NOTHING': 67, 'REAL': 131, 'CATCH': 39, 'PT:PRO3PL': 56, 'CANNOT': 3, 'WHY-BECAUSE': 63, 'THINK': 135, 'PLAY-1H': 2, 'FS:MORAL': 20, 'TEACH': 2, 'KEEP': 2, 'NEVER': 8, 'STORY': 43, 'LIE': 21, 'FS:EVEN': 4, 'WHEN': 10, 'FS:IS': 4, 'SAY': 101, 'CAT2': 68, 'RESENT': 3, 'FS:TWEETY': 11, 'BIRD': 128, 'PT:LOC': 397, 'SIT': 5, 'PLAN': 5, 'FS:HOW': 2, 'FS:GET': 3, 'FS:T-TWEETY': 1, 'HOW': 12, 'G:CAT-HANDS-ON-HIPS': 2, 'WALK': 52, 'GO-TO-AND-FRO': 11, 'WORK-OUT': 34, 'INVENT': 2, 'FS:DRAIN': 6, 'FS:PIPE': 38, 'DS(BC):SHAPE-AND-SIZE-OF-THE-PIPE': 1, 'GO-POINT': 47, 'GOOD': 205, 'DS(1):ANIMAL-ENTERS-THE-PIPE-FROM-THE-BOTTOM': 1, 'DSS(BC):VERTICAL-CYLINDER-DOWNPIPE': 102, 'DS(1):ANIMAL-IS-DETERMINED-TO-CLIMB-UP': 2, 'DS(BC>S):ANIMAL-USES-THE-CLIMBING-ROPE': 1, 'STAND': 42, 'FS:PUDDY': 1, 'DS(1):ANIMAL-GETS-OUT-OF-THE-PIPE': 1, 'PT:PRO1SG': 151, 'ZOOM-OFF': 17, 'G(CA):CARRY-BIG-BALL': 29, 'BOWLING': 76, 'BALL3': 11, 'DS(5):BIG-BALL': 1, 'G(CA):DROP-BIG-BALL': 3, 'DS(BENT5):THE-BALL-GOES-IN-THE-PIPE': 1, 'DS(BENT5):?': 2, 'DS(1):ANIMAL-CLIMBS-UP-IN-THE-PIPE': 2, 'DS(1):ANIMAL-CLIMBS-UP': 9, 'DS(S>BC):THE-BALL-HITS-THE-CAT': 1, "DS(1):THE-BALL-ENTERS-THE-CAT'S-MOUTH": 1, "DS(S):ANIMAL'S-HEAD-WITH-THE-BALL": 1, 'DS(S):ANIMAL-GOES-DOWN': 3, 'DS(S):THE-BALL-HITS-THE-CAT': 2, 'DS(1):ANIMAL-GOES-DOWN': 5, 'ESCAPE': 44, 'WHAT': 118, 'SWALLO': 1, 'SOME': 29, 'DS(B):ANIMAL-CLIMBS-UP': 3, 'GO-DOWN': 16, 'IN': 175, 'CAT': 156, 'STOMACH': 1, 'DSM(BENT2):ANIMAL-GETS-OUT-OF-THE-PIPE': 1, 'CAN-NOT': 36, 'DS(1):ANIMAL-STRADDLES': 5, '': 868, 'BOWL': 1, 'ROLL': 30, 'DOWN-B': 1, "DS(BENT5):ANIMAL'S-FUR-ON-ITS-NECK": 1, "DS(3):ANIMAL'S-EAR?": 1, 'ACCURATE': 4, 'G(5-UP):UMM': 15, 'BUILDING-H': 5, 'DS(5):THE-BUILDING': 1, 'DS(1):ANIMAL-ENTERS-THE-BUILDING': 2, 'DS(1):ANIMAL-HITS-THE-BOWLING-PINS': 1, 'EXPLODE': 5, 'FS:X': 1, 'DS(INDEFINITE):ALL-THE-PINS-FALLS': 1, "G(5-UP):THAT'S-IT": 29, 'PT:LOC(ILY)': 1, 'G(ILY):UMM': 1, 'LOOK(FALSE START)': 1, 'TELEPHONE1': 1, 'RINGING-PHONE-2H': 1, 'G(INDEFINITE):UMM': 1, 'FS:COUNTER': 1, 'DSS(5):COUNTER': 1, 'MAN': 107, 'SLIDE1(BENT2)': 1, 'CA:MAN': 2, 'GRAB-2H': 9, 'DSL(6):HOLDING-TELEPHONE': 1, 'PROUD1': 1, 'SPIDER': 1, 'HELLO1': 2, 'SURPRISE3': 3, 'PT:BUOY': 17, 'OLD': 51, 'LADY1': 97, 'TALK': 31, 'PT:PRO3SG(7)': 28, 'PLEASE2': 1, 'G(5):UMM': 11, 'HELP': 30, 'LUGGAGE': 6, 'G(BENT2):UMM': 1, 'ALRIGHT': 26, 'BUT2': 24, 'G(1):UMM': 15, 'CAT2(X)': 2, 'CHECK2': 2, 'LETTER': 2, 'DSS(B-LATERAL):PIGEON-HOLE': 1, 'HEAR2': 12, 'STEAL': 8, 'G:UMM': 8, 'PT:PRO3SG  ': 31, 'DISAPPEAR2': 28, 'UNIFORM': 3, 'CEILING': 2, 'FS:SERVICE': 1, 'STAND-1H': 3, 'KNOCK-1H': 3, 'PRETEND(7)': 1, 'CA:CAT': 11, 'DSM(S):LADY-PEERING-FROM-TOP': 1, 'PT:LOC/PRO  ': 1, 'FS:SERVICE(VICE)': 1, 'CA:OLD-LADY': 1, 'PT:PRO2SG  ': 34, 'EXCITED': 15, 'YES1': 2, 'DSM(S):MOVES-AWAY': 1, 'G:READY': 5, 'D ...
# 6689

# %% [markdown]
# ## number of actual words

# %%
def is_comprised_of_characters(input_string, allowed_characters):
    for char in input_string:
        if char not in allowed_characters:
            return False
    return True

# %%
import string

lowercase_characters = list(string.ascii_lowercase)
uppercase_characters = list(string.ascii_uppercase)
numWords = 0
otherWords = set()
onlyNumWords = {}
for word in allWords:
    if is_comprised_of_characters(word, lowercase_characters + uppercase_characters + ['-','(', ')', '1', '2','3','4']):
        numWords += 1
        onlyNumWords[word] = numAllWords[word]
    else:
        otherWords.add(word)
numWords
# Out:
# 1948

# %% [markdown]
# ## number of times each word is used

# %%
onlyNumWords.pop('')
total = 0
for key, value in onlyNumWords.items():
    total += value
averagenum = total/len(onlyNumWords)
print(averagenum, total)
# Out:
# 9.040061633281972 17601

# %%
folderLocation = 'D:/Auslan/AUSLANRECO-I0569/data/ELAR Data/'
folderList = os.listdir(folderLocation)

lowercase_characters = list(string.ascii_lowercase)
uppercase_characters = list(string.ascii_uppercase)
allWords = set()
i = 0
story = {}
for folderName in folderList:
    if folderName == '! Annotated Files' or folderName == "Readme.md":
        continue
    storyType = folderName.split(' - ')[1]

    if storyType not in story:
        story[storyType] = set()

    # ELAR File
    videoLocation = folderLocation + folderName
    videoName = folderName.split()[0]
    files = os.listdir(videoLocation)
    for file in files:
        if '.eaf' in file:
            eaf = Eaf(videoLocation + '/' + file)
    
    timeWords = []
    for key in list(eaf.tiers['RH-IDgloss'][0].keys()):
        start = eaf.timeslots[eaf.tiers['RH-IDgloss'][0][key][0]]
        end = eaf.timeslots[eaf.tiers['RH-IDgloss'][0][key][1]]
        word = eaf.tiers['RH-IDgloss'][0][key][2]
        if is_comprised_of_characters(word, lowercase_characters + uppercase_characters + ['-','(', ')', '1', '2','3','4']):
            story[storyType].add(word)
            allWords.add(word)
print(len(allWords))
# Out:
# c:\Users\KAI\.conda\envs\ml\lib\site-packages\pympi\Elan.py:1471: UserWarning: Parsing unknown version of ELAN spec... This could result in errors...
#   warnings.warn('Parsing unknown version of ELAN spec... '
# 1948

# %%
print(len(story['The Boy Who Cried Wolf']))
print(len(story['The Hare and the Tortoise']))
print(len(story['Frog Where Are You']))
print(len(story['Sign order elicitation task']))
print(len(story['Canary Row cartoon']))
# Out:
# 802
# 554
# 680
# 320
# 509

# %% [markdown]
# # BOBSL analysis

# %% [markdown]
# ## Number of words unverified

# %%
import json

# %%
# Opening JSON file
with open('D:/BOBSL/bobsl/dict_spottings.json') as json_file:
    data = dict(json.load(json_file))

# %%
allwords =  set(data['train'].keys()).union(set(data['test'].keys()).union(set(data['val'].keys())))
                                
print(len(allwords))
# Out:
# 6747

# %% [markdown]
# ## Number of words verified

# %%
# Opening JSON file
with open('D:/BOBSL/bobsl/verified_dict_spottings.json') as json_file:
    data = dict(json.load(json_file))

# %%
len(data['test'])
# Out:
# 761

# %% [markdown]
# ## average number of words

# %%
# Opening JSON file
with open('D:/BOBSL/bobsl/dict_spottings.json') as json_file:
    data = dict(json.load(json_file))
    auto = data

# %%
print(len(data['train']['1']['names']))
print(len(data['test']['1']['names']))
print(len(data['val']['1']['names']))
# Out:
# 26191
# 4457
# 613

# %%
combinedData = {}
print(combinedData)
i = 0
for sets in data:
    for key, value in data[sets].items():
        if key not in combinedData:
            combinedData[key] = value.copy()
            #{'probs':value['probs'], 'names'}
        else:
            combinedData[key]['probs'] = combinedData[key]['probs'] + data[sets][key]['probs']
            combinedData[key]['global_times'] = combinedData[key]['global_times'] + data[sets][key]['global_times']
            combinedData[key]['names'] = combinedData[key]['names'] + data[sets][key]['names']
        i += 1
len(combinedData)
# Out:
# {}
# 6747

# %%
total = 0
for key, value in combinedData.items():
    total += len(value['probs'])
print(total/len(combinedData))
# Out:
# 889.02549281162

# %%
total = 0
for key, value in data['train'].items():
    total += len(value['probs'])
print(total/len(data['train']))

total = 0
for key, value in data['test'].items():
    total += len(value['probs'])
print(total/len(data['test']))

total = 0
for key, value in data['val'].items():
    total += len(value['probs'])
print(total/len(data['val']))
# Out:
# 745.1690712353471
# 165.17934880374168
# 31.037755102040816

# %%
# Opening JSON file
with open('D:/BOBSL/bobsl/verified_dict_spottings.json') as json_file:
    data = dict(json.load(json_file))
    verified = data

# %%
total = 0
for key, value in data['test'].items():
    total += len(value['probs'])
print(total/len(data['test']), total)
# Out:
# 20.37976346911958 15509

# %% [markdown]
# ## Verify the quality of signs

# %%
import json

# %%
# Opening JSON file
with open('D:/BOBSL/bobsl/verified_dict_spottings.json') as json_file:
    data = dict(json.load(json_file))
    verified = data

# %%
# Opening JSON file
with open('D:/BOBSL/bobsl/dict_spottings.json') as json_file:
    data = dict(json.load(json_file))
    auto = data

# %%
import cv2
print(cv2.__version__)
import os
import numpy as np
signScore = {}
print(range(len(auto['test']['age'])))
print(len(auto['test']['age']['names']))
print(len(verified['test']['age']['names']))
print(auto['test']['age']['global_times'])
location = 'D:/BOBSL/BOBSL200G/bobsl/videos/'
playbackSpeed = int((1/25)*1000)

for i in range(25):
    videoName = auto['test']['age']['names'][i]
    videoLocation = location + videoName + '.mp4'
    if os.path.exists(videoLocation):
        print("Video: ", videoLocation, "exists")
        video_capture = cv2.VideoCapture(videoLocation)
        fps = video_capture.get(cv2.CAP_PROP_FPS)
        start = int(auto['test']['age']['global_times'][i] * fps)
        end = start + 20
        numFrame = 0
        videoFrames = []
        print("Caputuring frames")
        while True:
            ret, frame = video_capture.read()
            if not ret or numFrame > end:
                break
            if numFrame < start:
                numFrame += 1
                continue
            videoFrames.append(frame)
            numFrame += 1
        video_capture.release()
        print('Frames Caputred')
        if len(videoFrames) > 0:
            frameNum = 0
            while True:
                if frameNum >= len(videoFrames):
                    frameNum = 0
                try:
                    cv2.imshow('MediaPipe Pose', videoFrames[frameNum])
                except:
                    print(videoName, frameNum, len(videoFrames))
                    break
                frameNum += 1
                k = cv2.waitKey(playbackSpeed) & 0xFF
                if k == ord('q'):
                    break
                elif k == ord('p'):
                    signScore[videoName] = True
                elif k == ord('l'):
                    signScore[videoName] = False
            cv2.destroyAllWindows() 
        cv2.destroyAllWindows()
    else:
        print(videoName, 'does not exist')
    cv2.destroyAllWindows()
# Out:
# 4.8.0
# range(0, 3)
# 265
# 51
# [1371.68, 217.76, 2334.4, 1914.88, 3443.2, 1395.04, 1538.24, 2131.68, 448.64, 1514.4, 941.92, 815.84, 102.88, 592.16, 1677.28, 1684.0, 93.92, 940.0, 1167.2, 1447.2, 622.88, 2124.96, 2376.64, 200.96, 666.88, 1053.12, 1011.04, 1802.72, 1835.52, 666.72, 737.6, 756.64, 173.6, 2652.16, 279.2, 369.28, 474.56, 1052.8, 1076.32, 1240.64, 1374.24, 2468.0, 2713.6, 2806.72, 3124.0, 3226.88, 3420.64, 3463.52, 3497.6, 36.64, 574.24, 2213.92, 2419.68, 2745.92, 3515.2, 710.56, 470.72, 1121.44, 3457.12, 2798.88, 375.36, 1824.96, 1854.72, 2111.2, 1582.88, 2702.88, 691.52, 239.68, 2769.92, 3503.2, 46.72, 337.28, 1306.72, 3080.32, 41.28, 1454.08, 2901.6, 3491.04, 1083.68, 1493.92, 1563.36, 339.36, 339.36, 488.32, 925.92, 463.52, 1375.84, 1375.84, 521.92, 3204.32, 1776.0, 1618.88, 3012.8, 1541.6, 2137.28, 2690.56, 600.64, 713.6, 733.92, 1431.04, 1624.8, 1385.6, 2408.0, 199.68, 1430.4, 524.96, 911.68, 1762.24, 2656.96, 3419.68, 1610.72, 481.12, 2565.76, 650.72, 317.28, 756.48, 762.08, 1435.04, 312.32, 933.44, 787.52, 1607.36, 1258.72, 769.44, 1189.28, 479.2, 1047.04, 1641.92, 2725.76, 159.68, 299.36, 1052.48, 1766.88, 771.2, 1133.92, 857.44, 2466.56, 2466.56, 3004.8, 687.84, 909.92, 45.28, 290.88, 553.12, 613.76, 149.92, 1775.04, 2606.88, 2824.64, 616.64, 616.64, 788.32, 831.68, 869.44, 944.16, 965.28, 974.08, 1008.48, 1940.0, 2952.16, 1016.48, 2687.2, 2708.16, 1261.92, 2756.96, 535.04, 1715.84, 2174.72, 3370.4, 3476.64, 172.16, 313.92, 363.36, 2661.12, 449.28, 1223.2, 1536.8, 3467.68, 179.68, 188.0, 3158.72, 3172.32, 3413.12, 1505.92, 1518.88, 1622.24, 1791.68, 3520.0, 2462.72, 2753.28, 3158.4, 412.48, 314.72, 392.64, 423.52, 654.08, 1153.76, 2211.36, 1164.0, 1508.8, 2067.84, 1065.6, 1206.24, 1251.68, 2550.56, 2309.92, 2447.36, 2447.36, 1092.16, 1855.84, 2827.84, 1105.44, 305.6, 717.92, 903.84, 968.32, 968.64, 1517.76, 737.44, 1104.0, 462.88, 196.32, 2453.44, 3111.04, 3224.64, 72.48, 2165.92, 2690.24, 1062.56, 1703.84, 43.84, 51.36, 127.52, 243.36, 2838.56, 2744.32, 2336.8, 2904.32, 3246.24, 1223.84, 3207.04, 3239.52, 3273.28, 1974.72, 2924.0, 3372.32, 1630.72, 214.08, 3053.12, 3083.68, 3084.0, 1570.08, 746.72, 38.72, 121.6, 306.08, 196.0, 2891.36, 3551.04, 579.52, 1390.72, 1746.72, 1901.28, 13.44, 245.76]
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5130659699728866130.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5164062518553105701.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5200034588474236194.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5257918721715904053.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5257918721715904053.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5276110913861331583.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5276110913861331583.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5276110913861331583.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5289124665598453320.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5329907957054353271.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5330646261102337888.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5387174902698595688.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5404512826645859441.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5417897663557321397.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5417897663557321397.mp4 exists
# Caputuring frames
# Frames Caputred
# Video:  D:/BOBSL/BOBSL200G/bobsl/videos/5417897663557321397.mp4 exists
# Caputuring frames
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\KAI\Documents\UQ\REIT4841\Classification-for-Auslan\ThesisAnalysis.ipynb Cell 37 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/KAI/Documents/UQ/REIT4841/Classification-for-Auslan/ThesisAnalysis.ipynb#X51sZmlsZQ%3D%3D?line=23'>24</a> print("Caputuring frames")
#      <a href='vscode-notebook-cell:/c%3A/Users/KAI/Documents/UQ/REIT4841/Classification-for-Auslan/ThesisAnalysis.ipynb#X51sZmlsZQ%3D%3D?line=24'>25</a> while True:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/KAI/Documents/UQ/REIT4841/Classification-for-Auslan/ThesisAnalysis.ipynb#X51sZmlsZQ%3D%3D?line=25'>26</a>     ret, frame = video_capture.read()
#      <a href='vscode-notebook-cell:/c%3A/Users/KAI/Documents/UQ/REIT4841/Classification-for-Auslan/ThesisAnalysis.ipynb#X51sZmlsZQ%3D%3D?line=26'>27</a>     if not ret or numFrame > end:
#      <a href='vscode-notebook-cell:/c%3A/Users/KAI/Documents/UQ/REIT4841/Classification-for-Auslan/ThesisAnalysis.ipynb#X51sZmlsZQ%3D%3D?line=27'>28</a>         break
#
# KeyboardInterrupt:

# %%
import cv2
print(cv2.__version__)
import os
import numpy as np
signScore = {}
print(range(len(auto['test']['age'])))
print(len(auto['test']['age']['names']))
print(len(verified['test']['age']['names']))
print(auto['test']['age']['global_times'])
location = 'D:/BOBSL/BOBSL200G/bobsl/videos/'
playbackSpeed = int((1/25)*1000)

for i in range(15):
    videoName = verified['test']['age']['names'][i]
    videoLocation = location + videoName + '.mp4'
    if os.path.exists(videoLocation):
        print("Video: ", videoLocation, "exists")
        video_capture = cv2.VideoCapture(videoLocation)
        fps = video_capture.get(cv2.CAP_PROP_FPS)
        start = int(verified['test']['age']['global_times'][i] * fps)
        end = start + 20
        numFrame = 0
        videoFrames = []
        print("Caputuring frames")
        while True:
            ret, frame = video_capture.read()
            if not ret or numFrame > end:
                break
            if numFrame < start:
                numFrame += 1
                continue
            videoFrames.append(frame)
            numFrame += 1
        video_capture.release()
        print('Frames Caputred')
        if len(videoFrames) > 0:
            frameNum = 0
            while True:
                if frameNum >= len(videoFrames):
                    frameNum = 0
                try:
                    cv2.imshow('MediaPipe Pose', videoFrames[frameNum])
                except:
                    print(videoName, frameNum, len(videoFrames))
                    break
                frameNum += 1
                k = cv2.waitKey(playbackSpeed) & 0xFF
                if k == ord('q'):
                    break
                elif k == ord('p'):
                    signScore[videoName] = True
                elif k == ord('l'):
                    signScore[videoName] = False
            cv2.destroyAllWindows() 
        cv2.destroyAllWindows()
    else:
        print(videoName, 'does not exist')
    cv2.destroyAllWindows()
